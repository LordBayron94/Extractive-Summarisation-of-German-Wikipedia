# %%
import os, networkx as nx, collections, re
import pandas as pd
import numpy as np
#from HanTa import HanoverTagger as ht
import nltk, string
from nltk.stem.snowball import GermanStemmer
from nltk.stem import PorterStemmer
from nltk import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics, neighbors
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from pprint import pprint
nltk.download('wordnet')
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import FunctionTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from scipy import sparse
from sklearn.metrics import plot_confusion_matrix
nltk.download('wordnet') # first-time use only
nltk.download('stopwords')
nltk.download('punkt')
from gensim.models import Word2Vec, word2vec
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('/content/data_class.csv', encoding='utf-8')
df = df.drop(['Unnamed: 0.1'], axis=1)
df
# Out:
#          Unnamed: 0  ... sim_sent
# 0                 0  ...        1
# 1                 1  ...        0
# 2                 2  ...        0
# 3                 3  ...        0
# 4                 4  ...        0
# ...             ...  ...      ...
# 3513930     3513930  ...        1
# 3513931     3513931  ...        0
# 3513932     3513932  ...        1
# 3513933     3513933  ...        0
# 3513934     3513934  ...        1
#
# [3513935 rows x 6 columns]

# %%
df['sim_sent'] = np.where((df.noCap_LetterWords_inSentence>8.0) | (df.no_words_inSent_SS>=2.0), 'Yes', 'No')

# %%
df.sort_values('Unnamed: 0', axis=0, inplace=True)

# %%
train_size = int(len(df) * 0.5)
train_df = df.iloc[:train_size,:]
test_df = df.iloc[train_size:,:]

# %%
test_df
# Out:
#          Unnamed: 0  ... sim_sent
# 1756967     1756967  ...      Yes
# 1756968     1756968  ...       No
# 1756969     1756969  ...      Yes
# 1756970     1756970  ...      Yes
# 1756971     1756971  ...       No
# ...             ...  ...      ...
# 3513930     3513930  ...       No
# 3513931     3513931  ...      Yes
# 3513932     3513932  ...      Yes
# 3513933     3513933  ...      Yes
# 3513934     3513934  ...      Yes
#
# [1756968 rows x 6 columns]

# %%
n_pos_train = sum(train_df['sim_sent'] == 'Yes')
print('Training set contains {:.2%} positive reviews'.format(n_pos_train/len(train_df)))
n_pos_test = sum(test_df['sim_sent'] == 'Yes')
print('Test set contains {:.2%} positive reviews'.format(n_pos_test/len(test_df)))
# Out:
# Training set contains 40.17% positive reviews
# Test set contains 41.54% positive reviews

# %%
stopword_list = nltk.corpus.stopwords.words('german')
def sentence_to_wordlist(sentence, remove_stopwords=False):
    sentence_text = re.sub("[^a-zA-Z]"," ", sentence)
    
    # convert to lower case and split at whitespace
    words = sentence_text.lower().split()
    
    # remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopword_list)
        words = [w for w in words if not w in stops]

    return words

# %%
def text_to_sentences(sentence, remove_stopwords=False):
    # use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = sent_tokenize(sentence, language = "german")

    # each sentence is furthermore split into words
    sentences = []    
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            sentences.append(sentence_to_wordlist(raw_sentence, remove_stopwords))
            
    return sentences

# %%
train_sentences = []  # Initialize an empty list of sentences
for sent in train_df['source1']:
    train_sentences += text_to_sentences(sent)

# %%
from gensim.models import Word2Vec, word2vec
import logging
import matplotlib.pyplot as plt
import nltk
import numpy as np
from nltk.corpus import stopwords
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.pipeline import Pipeline
import sqlite3
import re
from tqdm import tqdm

# %%
model_name = 'train_model'
# Set values for various word2vec parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 3       # Number of threads to run in parallel
context = 10          # Context window size
downsampling = 1e-3   # Downsample setting for frequent words
if not os.path.exists(model_name): 
    # Initialize and train the model (this will take some time)
    model = word2vec.Word2Vec(train_sentences, workers=num_workers, \
                size=num_features, min_count = min_word_count, \
                window = context, sample = downsampling)

    # If you don't plan to train the model any further, calling 
    # init_sims will make the model much more memory-efficient.
    model.init_sims(replace=True)

    # It can be helpful to create a meaningful model name and 
    # save the model for later use. You can load it later using Word2Vec.load()
    model.save(model_name)
else:
    model = Word2Vec.load(model_name)

# %%
def make_feature_vec(words, model, num_features):
    """
    Average the word vectors for a set of words
    """
    feature_vec = np.zeros((num_features,),dtype="float32")  # pre-initialize (for speed)
    nwords = 0.
    index2word_set = set(model.wv.index2word)  # words known to the model

    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1.
            feature_vec = np.add(feature_vec,model[word])
    
    feature_vec = np.divide(feature_vec, nwords)
    return feature_vec


def get_avg_feature_vecs(reviews, model, num_features):
    """
    Calculate average feature vectors for all reviews
    """
    counter = 0
    review_feature_vecs = np.zeros((len(reviews),num_features), dtype='float32')  # pre-initialize (for speed)
    
    for review in reviews:
        print(review)
        review_feature_vecs[counter] = make_feature_vec(review, model, num_features)
        counter = counter + 1
    return review_feature_vecs

# %%
clean_train_sent = []
for sent in train_df['source1']:
    clean_train_sent.append(sentence_to_wordlist(sent, remove_stopwords=True))
trainDataVecs = get_avg_feature_vecs(clean_train_sent, model, num_features)
# Out:
# ['minghella', 'sohn', 'italienisch', 'schottischer', 'eltern', 'isle', 'of', 'wight', 'fabrik', 'fu', 'r', 'eiscreme', 'betrieben']
# ['schulabschluss', 'studierte', 'universita', 't', 'hull', 'zeit', 'lang', 'dozent', 'ta', 'tig']
# ['drehte', 'ersten', 'kurzfilm']
# ['seit', 'autor', 'story', 'editor', 'ta', 'tig']
# ['wurde', 'theaterstu', 'cken', 'rundfunkho', 'rspielen', 'fernsehserie', 'inspector', 'morse', 'vielen', 'drehbu', 'chern', 'fu', 'r', 'film', 'fernsehen', 'bekannt']
# ['entwickelte', 'drehbu', 'cher', 'fu', 'r', 'erfolgreich', 'ausgestrahlte', 'fernsehserie', 'the', 'storyteller', 'muppets', 'erfinder', 'jim', 'henson']
# ['produzent', 'erfolgreich', 'darunter', 'fu', 'r', 'filme', 'stille', 'amerikaner', 'dolmetscherin', 'vorleser', 'fu', 'r', 'posthum', 'fu', 'r', 'oscar', 'nominiert', 'wurde']
# ['gemeinsam', 'freund', 'kollegen', 'sydney', 'pollack', 'gru', 'ndete', 'produktionsfirma', 'mirage', 'enterprises']
# ['regisseur', 'minghella', 'galt', 'guter', 'schauspielerfu', 'hrer', 'regie', 'brachten', 'zahlreiche', 'darsteller', 'oscar', 'nominierungen', 'zwei', 'schauspielerinnen', 'erhielten', 'auszeichnung', 'beste', 'nebendarstellerin', 'juliette', 'binoche', 'rene', 'e', 'zellweger']
# ['ende', 'lebens', 'kehrte', 'minghella', 'anfa', 'ngen', 'radio', 'bu', 'hne', 'zuru', 'ck', 'wurde', 'ho', 'rspiel', 'eyes', 'down', 'looking', 'jude', 'law', 'ehren', 'samuel', 'beckett', 'bbc', 'radio', 'ausgestrahlt', 'jahr', 'zuvor', 'inszenierung', 'puccini', 'oper', 'madame', 'butterfly', 'english', 'national', 'opera', 'london', 'premiere', 'wurde', 'nationaloper', 'vilnius', 'metropolitan', 'opera', 'new', 'york', 'gezeigt']
# ['ende', 'films', 'abbitte', 'joe', 'wright', 'kurzauftritt', 'talkshow', 'moderator', 'neben', 'vanessa', 'redgrave']
# ['letzte', 'arbeit', 'drehbuchautor', 'skript', 'fu', 'r', 'musical', 'film', 'nine']
# ['letzten', 'regiearbeiten', 'za', 'hlt', 'pilotfilm', 'krimiserie', 'detektivin', 'fu', 'r', 'botswana', 'bbc', 'fu', 'nf', 'tage', 'tod', 'erstmals', 'ausstrahlte']
# ['minghella', 'hongkong', 'stammenden', 'choreographin', 'produzentin', 'schauspielerin', 'carolyn', 'choa', 'verheiratet']
# ['ehe', 'entstammen', 'zwei', 'kinder', 'filmbranche', 'ta', 'tig', 'tochter', 'hannah', 'minghella', 'produktion', 'sohn', 'max', 'minghella', 'schauspieler']
# ['tante', 'edana', 'minghella', 'onkel', 'dominic', 'minghella', 'drehbuchautoren']
# ['minghella', 'starb', 'alter', 'jahren', 'londoner', 'krankenhaus', 'inneren', 'blutungen', 'infolge', 'operation', 'tonsillenkarzinoms', 'karzinoms', 'nacken']
# ['erhielt', 'minghella', 'londoner', 'kritikerpreis', 'meistversprechender', 'junger', 'dramatiker', 'kritikerpreis', 'fu', 'r', 'stu', 'ck', 'made', 'bangkok', 'bestes', 'stu', 'ck', 'saison']
# ['erhielt', 'fu', 'r', 'englische', 'patient', 'oscar', 'rubrik', 'beste', 'regie', 'oscar', 'nominierung', 'kategorie', 'bestes', 'adaptiertes', 'drehbuch', 'fu', 'r', 'talentierte', 'mr', 'ripley', 'regie', 'fu', 'hrte']
# ['wurde', 'minghella', 'commander', 'of', 'the', 'british', 'empire', 'ernannt']
# ['pra', 'sident', 'british', 'film', 'institute']
# ['seit', 'tra', 'gt', 'anthony', 'minghella', 'theatre', 'isle', 'of', 'wight', 'namen']
# ['ende', 'jahre', 'wurde', 'erste', 'auteur', 'theorie', 'franzo', 'sischen', 'filmkritiker', 'alexandre', 'astruc', 'formuliert', 'frage', 'geistigen', 'besitz', 'films', 'aufwarf']
# ['traditionellen', 'schaffensprozess', 'lassen', 'anteile', 'drehbuchautor', 'kameramann', 'filmregisseur', 'gesamtwerk', 'schwer', 'zuordnen']
# ['zuteilung', 'teilaufgaben', 'honorarta', 'tigkeit', 'filmgesellschaften', 'leide', 'kreativita', 't', 'these']
# ['umkehrschluss', 'fordert', 'theorie', 'zusammenfu', 'hrung', 'ta', 'tigkeiten', 'kreativen', 'einheit']
# ['formulierte', 'entwurf', 'aufsatz', 'la', 'came', 'ra', 'stylo']
# ['kamera', 'stift', 'verwendet']
# ['sicher', 'bedeutende', 'schriften', 'zukunft', 'mehr', 'text', 'kamera', 'geschrieben', 'wu', 'rden']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if sys.path[0] == '':
# ['durchgesetzt', 'a', 'hnliche', 'ideen', 'auteur', 'theorie', 'erst', 'jahren']
# ['deren', 'ga', 'ngiger', 'begriff', 'wegbereiter', 'fu', 'r', 'heutige', 'auteur', 'theorie', 'lautete', 'zuna', 'chst', 'politique', 'auteurs', 'erst', 'laufe', 'zeit', 'theorie', 'umgeformt', 'wurde']
# ['wort', 'politique', 'bzw']
# ['politik', 'stand', 'eher', 'fu', 'r', 'parteilichkeit', 'fu', 'r', 'filmwissenschaftliche', 'diskussionen', 'eher', 'hinderlich']
# ['politique', 'auteurs', 'wurde', 'zeit', 'gruppe', 'jungen', 'filmkritikern', 'andre', 'bazin', 'entwickelt', 'fu', 'r', 'filmzeitschrift', 'cahiers', 'cine', 'ma', 'schrieben']
# ['wesentliche', 'rolle', 'spielte', 'dabei', 'franc', 'ois', 'truffaut', 'januar', 'vero', 'ffentlichte', 'aufsehen', 'erregenden', 'aufsatz', 'gewisse', 'tendenz', 'franzo', 'sischen', 'film', 'scharfer', 'polemik', 'etablierten', 'franzo', 'sischen', 'qualita', 'tsfilm', 'wandte']
# ['trat', 'regisseur', 'gegenu', 'ber', 'drehbuchautor', 'autor', 'literarischen', 'vorlage', 'oft', 'hintergrund']
# ['truffaut', 'pla', 'dierte', 'dagegen', 'fu', 'r', 'film', 'form', 'inhalt', 'vollsta', 'ndig', 'regisseur', 'eigentlichen', 'auteur', 'films', 'bestimmt']
# ['fand', 'traditionell', 'autoren', 'filme', 'betrachteten', 'europa', 'ischen', 'regisseuren', 'luis', 'bun', 'uel', 'jean', 'renoir', 'roberto', 'rossellini', 'ausserdem', 'regisseuren', 'alfred', 'hitchcock', 'howard', 'hawks', 'fritz', 'lang', 'vincente', 'minnelli', 'studiosystem', 'hollywoods', 'arbeiteten', 'deren', 'filme', 'trotzdem', 'perso', 'nlichen', 'stil', 'aufweisen']
# ['konzept', 'regisseurs', 'auteur', 'filme', 'wurde', 'fu', 'r', 'filmkritik', 'cahiers', 'cine', 'ma', 'bestimmend', 'fu', 'r', 'regisseure', 'nouvelle', 'vague', 'daraus', 'hervorgingen', 'neben', 'truffaut', 'etwa', 'jean', 'luc', 'godard', 'jacques', 'rivette', 'claude', 'chabrol', 'filmemacher', 'umsetzung', 'ku', 'nstlerischen', 'ziele', 'jeweils', 'ganz', 'eigenen', 'filmischen', 'form', 'bedienten']
# ['roland', 'barthes', 'hingegen', 'misst', 'essay', 'la', 'mort', 'de', 'l', 'auteur', 'autor', 'fu', 'r', 'literatur', 'weitaus', 'geringere', 'bedeutung', 'bisher', 'fall']
# ['auteur', 'dieu', 'barthes', 'e', 'crivain', 'ersetzt', 'folgt', 'kritik', 'julia', 'kristeva', 'bereits', 'aufsatz', 'bakhtine', 'le', 'mot', 'le', 'dialogue', 'et', 'le', 'roman', 'aufbrachte']
# ['fu', 'r', 'europa', 'ischen', 'film', 'blieb', 'auteur', 'theorie', 'pra', 'gend']
# ['danach', 'setzte', 'abkehr', 'verha', 'ngnisvollen', 'macht', 'regisseure']
# ['wirtschaftlicher', 'druck', 'zwang', 'ru', 'ckkehr', 'arbeitsteiligen', 'produktionsweise', 'fu', 'r', 'produzenten', 'film', 'charakteristisch']
# ['einher', 'ging', 'notwendigerweise', 'einigung', 'beteiligten', 'kleinsten', 'gemeinsamen', 'nenner', 'somit', 'ha', 'ufig', 'gewisse', 'banalisierung', 'filminhalte', 'umso', 'sta', 'rker', 'tage', 'tritt', 'je', 'weniger', 'produzent', 'projektverantwortlicher', 'eigentlichen', 'scho', 'pferischen', 'prozess', 'eingebunden']
# ['filmwissenschaft', 'wurden', 'immer', 'neue', 'autorschaften', 'teammitgliedern', 'entdeckt']
# ['realita', 't', 'film', 'teamarbeit', 'film', 'anzusehen', 'beispiel', 'idee', 'fu', 'r', 'einstellung', 'regisseur', 'kameramann', 'stammt']
# ['dogma', 'film', 'kameramann', 'weisungsgebunden']
# ['polnische', 'schule', 'bindet', 'kameramann', 'bereits', 'prozess', 'drehbuchschreibens']
# ['unerfahrene', 'regisseure', 'meist', 'kreativita', 't', 'kameramanns', 'kamerafrau', 'teammitglieder', 'angewiesen']
# ['aufkommen', 'digitaler', 'aufnahmetechniken', 'digital', 'video', 'seit', 'ende', 'jahre', 'sehen', 'viele', 'filmemacher', 'etwa', 'wim', 'wenders', 'gu', 'nstigere', 'bedingungen', 'fu', 'r', 'individuelle', 'subjektive', 'produktionen', 'gegeben']
# ['franc', 'ois', 'truffaut', 'jean', 'luc', 'godard', 'proklamierte', 'politique', 'auteurs', 'fu', 'nfziger', 'jahre', 'urspru', 'nglich', 'versuch', 'bestimmte', 'regisseure', 'alfred', 'hitchcock', 'ku', 'nstler', 'anzuerkennen', 'vo', 'llig', 'eigene', 'bildsprache', 'entwickelten', 'truffaut', 'selber', 'sa', 'mtliche', 'aspekte', 'filme', 'bestimmten']
# ['autorenfilmer', 'demnach', 'regisseur', 'film', 'mo', 'glichst', 'kompromisse', 'gestaltet', 'mo', 'chte']
# ['politique', 'auteurs', 'geriet', 'schnell', 'kritik']
# ['kritiker', 'andrew', 'sarris', 'peter', 'wiesen', 'empirisches', 'problem', 'niemand', 'beweisen', 'einfluss', 'regisseur', 'wirklich', 'filme', 'bzw']
# ['einfluss', 'form', 'inhalt', 'wirklich', 'autorschaft', 'wahrnehmen']
# ['beispiel', 'hierfu', 'r', 'gilt', 'vorspann', 'vertigo', 'reich', 'toten', 'alfred', 'hitchcock', 'angefertigt', 'tatsache', 'viele', 'filme', 'buchvorlage', 'fremder', 'autoren', 'basieren', 'drehbu', 'cher', 'selten', 'stammten']
# ['gerade', 'hitchcock', 'zentrale', 'figur', 'politique', 'auteurs']
# ['name', 'politique', 'auteurs', 'sagt', 'handelte', 'politik', 'gezielten', 'polemischen', 'eingriff']
# ['village', 'voice', 'kritiker', 'andrew', 'sarris', 'u', 'bersetzte', 'politique', 'auteurs', 'jedoch', 'auteur', 'theory', 'wobei', 'unklar', 'blieb', 'sinne', 'tatsa', 'chlich', 'theorie', 'handelt']
# ['sarris', 'popularisierte', 'theorie', 'englischen', 'sprachraum', 'benutzte', 'absolute', 'u', 'berlegenheit', 'hollywood', 'kinos', 'darzulegen', 'davon', 'u', 'berzeugt', 'sei', 'the', 'only', 'cinema', 'the', 'world', 'worth', 'exploring', 'depth', 'beneath', 'the', 'frosting', 'of', 'a', 'few', 'great', 'directors', 'at', 'the', 'top']
# ['frage', 'grenze']
# ['wen', 'vielmehr', 'nehmen', 'autor', 'wahr']
# ['soziologisch', 'gesehen', 'autorentheorie', 'distinktionsstrategie', 'junger', 'kritiker', 'aufmerksam', 'wollten']
# ['godard', 'spa', 'ter', 'offen', 'zugegeben', 'sagten', 'preminger', 'regisseuren', 'fu', 'r', 'studios', 'arbeiteten', 'heute', 'fu', 'rs', 'fernsehen', 'arbeitet', 'lohnempfa', 'nger', 'gleichzeitig', 'mehr', 'talent', 'sogar', 'genie', 'total', 'falsch']
# ['gesagt', 'glaubten', 'wirklichkeit', 'steckt', 'dahinter', 'aufmerksam', 'wollten', 'niemand', 'ho', 'rte']
# ['tu', 'ren']
# ['deshalb', 'mussten', 'sagen', 'hitchcock', 'gro', 'sseres', 'genie', 'chateaubriand']
# ['siebziger', 'jahren', 'folgte', 'sta', 'rkste', 'kritik', 'politique', 'auteurs']
# ['roland', 'barthes', 'proklamierte', 'bereits', 'poststrukturalistischen', 'hintergrund', 'tod', 'autors']
# ['autor', 'wurde', 'aufgrund', 'empirischen', 'dilemmas', 'beweisbarkeit', 'autorschaften', 'image', 'figur', 'erkannt', 'umwelt', 'formt', 'werke', 'einschreibt']
# ['feministischer', 'seite', 'wurde', 'politique', 'auteurs', 'scharf', 'angegriffen', 'diene', 'kollektiven', 'charakter', 'filmemachens', 'verdecken', 'tradition', 'patriarchaler', 'heldenverehrung', 'ma', 'nner', 'superstars', 'stilisieren']
# ['claire', 'johnston', 'verteidigte', 'ansatz', 'insofern', 'monolithischen', 'sicht', 'hollywood', 'kinos', 'entgegenwirke']
# ['neunziger', 'jahren', 'schliesslich', 'ging', 'tendenz', 'annahme', 'autorschaften', 'grossteil', 'konstruiert']
# ['timothy', 'corrigan', 'nennt', 'commercial', 'auteur']
# ['gerechnet', 'publikum', 'film', 'autor', 'bekannten', 'regisseurs', 'z']
# ['b']
# ['neue', 'woody']
# ['wahrnimmt', 'wirklich', 'wissen', 'einfluss', 'woody', 'tatsa', 'chlich', 'film']
# ['dana', 'polan', 'verfolgte', 'weiteren', 'interessanten', 'ansatz', 'sieht', 'auteurist', 'hauptverantwortlichen', 'fu', 'r', 'konstruierte', 'autorenbilder']
# ['kritiker', 'autor', 'ho', 'chste', 'instanz', 'suchen', 'franc', 'ois', 'truffaut', 'filmemacher', 'ku', 'nstler', 'hinweisen', 'nebenbei', 'eigene', 'erkenntniskraft', 'zelebrieren']
# ['begriff', 'dafu', 'r', 'lautet', 'auteur', 'desire']
# ['ansatz', 'zeigt', 'gro', 'ssten', 'vorwurf', 'gegenu', 'ber', 'politique', 'auteurs']
# ['trotzdem', 'nennung', 'regisseurs', 'parallel', 'beispielsweise', 'buchautor', 'scho', 'pfergeist', 'reflektierenden', 'filmkritikern', 'wissenschaftlern', 'weiterhin', 'ausserordentlich', 'beliebt']
# ['steckt', 'mehr', 'dahinter']
# ['neuerer', 'ansatz', 'kontextorientierte', 'werkanalyse', 'jan', 'distelmeyer', 'versucht', 'frage', 'kla', 'ren']
# ['grundlage', 'dienen', 'publikums', 'kritikerrezeption', 'seite', 'konstruktion', 'autors', 'biografie', 'filmindustrie', 'kulturellem', 'umfeld', 'seite']
# ['zweiseitige', 'anna', 'herung', 'erkennt', 'empirische', 'dilemma', 'definition', 'auteur', 'masst', 'bestimmung', 'eigentlich', 'werk', 'autor', 'xyz']
# ['viele', 'filmtheoretiker', 'verfolgen', 'heutzutage', 'a', 'hnliche', 'konzepte']
# ['solch', 'freie', 'handhabung', 'problem', 'vollsta', 'ndig', 'lo', 'sen', 'wichtigsten', 'elemente', 'variabel', 'eindeutigen', 'aussage', 'verschliessen']
# ['schwerpunkt', 'kritischer', 'tendenzen', 'liegt', 'grossteil', 'empirie']
# ['filmemacher', 'auteur', 'anzuerkennen', 'fordert', 'uneingeschra', 'nktes', 'vertrauen', 'aussagen', 'einfluss', 'eigenen', 'filme']
# ['zeiten', 'starken', 'vermarktung', 'mo', 'glichen', 'mehr', 'weniger', 'abha', 'ngigen', 'regisseure', 'seitens', 'filmindustrie', 'verleih', 'fast', 'aussichtsloses', 'unterfangen', 'restzweifel', 'stete', 'hinterfragen', 'auteur', 'definition', 'angebracht']
# ['al', 'pacino', 'geboren', 'manhattan', 'sohn', 'salvatore', 'pacino', 'geboren', 'sizilianischen', 'stadt', 'corleone', 'rose', 'gerard', 'tochter', 'italienischen', 'einwanderers', 'italienisch', 'amerikanischen', 'mutter', 'new', 'york', 'geboren', 'wurde']
# ['eltern', 'liessen', 'scheiden', 'zwei', 'jahre', 'alt']
# ['scheidung', 'zogen', 'al', 'mutter', 'bronx', 'pacino', 'wuchs', 'sizilianischen', 'grosseltern', 'heimatstadt', 'vaters', 'eingewandert', 'new', 'yorker', 'south', 'bronx']
# ['vater', 'salvatore', 'covina', 'zog', 'arbeitete', 'versicherungsagent', 'besass', 'restaurant', 'pacino', 's', 'lounge']
# ['pacino', 's', 'wurde', 'wirtschaftlich', 'schweren', 'zeiten', 'fru', 'hen', 'jahren', 'geschlossen', 'heute', 'tra', 'gt', 'namen', 'citrus', 'grill']
# ['salvatore', 'pacino', 'starb']
# ['januar', 'alter', 'jahren']
# ['al', 'pacino', 'stiefsohn', 'schauspielerin', 'maskenbildnerin', 'katherin', 'kovin', 'pacino', 'vier', 'schwestern', 'josette', 'lehrerin', 'zwillinge', 'roberta', 'paula', 'sowie', 'desiree', 'vater', 'vierten', 'ehe', 'adoptierte']
# ['jahren', 'wurde', 'pacino', 'schule', 'verwiesen', 'ging', 'fortan', 'manhattan', 'school', 'of', 'performing', 'arts']
# ['nebenher', 'arbeitete', 'kleineren', 'theatern', 'platzanweiser', 'kartenabreisser']
# ['abschluss', 'renommierten', 'lee', 'strasberg', 'theatre', 'and', 'film', 'institute', 'angesehenen', 'schauspiellehrer', 'herbert', 'berghof', 'begann', 'schauspielkarriere']
# ['pacino', 'interessierte', 'schon', 'kind', 'fu', 'r', 'schauspielerei']
# ['verfeinerte', 'talent', 'zwei', 'renommierten', 'new', 'yorker', 'schauspielschulen', 'studios', 'herbert', 'berghoff', 'actors', 'studio']
# ['spielte', 'mehreren', 'erfolgreichen', 'theaterstu', 'cken', 'debu', 'tstu', 'ck', 'the', 'connection', 'the', 'indian', 'wants', 'the', 'bronx', 'fu', 'r', 'obie', 'award', 'ausgezeichnet', 'wurde']
# ['wirkte', 'ersten', 'hollywood', 'produktion', 'natalie']
# ['erhielt', 'neben', 'kitty', 'winn', 'rolle', 'film', 'panik', 'needle', 'park', 'fu', 'r', 'rolle', 'michael', 'corleone', 'francis', 'ford', 'coppolas', 'pate', 'ebnete', 'erste', 'oscar', 'nominierung', 'einbrachte']
# ['hundstage', 'wurde', 'stiller', 'pacino']
# ['erst', 'jahren', 'brachte', 'filme', 'brian', 'de', 'palmas', 'scarface', 'sea', 'of', 'love', 'melodie', 'todes', 'gespra', 'ch']
# ['erneuten', 'zusammenarbeit', 'coppola', 'pate', 'iii', 'folgte', 'thriller', 'heat', 'schauspielkollege', 'robert', 'de', 'niro']
# ['ma', 'nnliche', 'hauptrolle', 'film', 'pretty', 'woman', 'lehnte', 'ab']
# ['darstellung', 'aids', 'kranken', 'schwulenhassers', 'roy', 'cohn', 'miniserie', 'engel', 'amerika', 'brachte', 'zahlreiche', 'preise', 'wurde', 'kritik', 'hoch', 'gelobt']
# ['pacino', 'dafu', 'r', 'bekannt', 'rollen', 'extrem', 'auszufu', 'llen']
# ['wa', 'hrend', 'spiel', 'jahren', 'insbesondere', 'pate', 'dabei', 'zumeist', 'minimalistisch', 'a', 'nderte', 'comeback', 'jahren', 'radikal']
# ['pacinos', 'exaltierte', 'darstellungen', 'filmen', 'scarface', 'auftrag', 'teufels', 'verdammten', 'sonntag', 'duft', 'frauen', 'wurden', 'kritikern', 'oftmals', 'overacting', 'bezeichnet']
# ['fu', 'r', 'grossteil', 'publikums', 'zeichnet', 'allerdings', 'genau', 'art', 'weise', 'gro', 'ssten', 'charakterdarsteller', 'gegenwart']
# ['viele', 'filme', 'darunter', 'glengarry', 'glen', 'ross', 'zuna', 'chst', 'floppte', 'za', 'hlen', 'heute', 'besten', 'genres']
# ['neben', 'karriere', 'filmschauspieler', 'arbeitet', 'weiterhin', 'regelma', 'ssig', 'verschiedenen', 'theatern', 'sowohl', 'darsteller', 'regisseur', 'produzent']
# ['fu', 'r', 'rollen', 'bu', 'hneninszenierungen', 'the', 'basic', 'training', 'of', 'pavlo', 'hummel', 'david', 'rabe', 'does', 'a', 'tiger', 'wear', 'a', 'necktie']
# ['don', 'petersen', 'erhielt', 'jeweils', 'tony', 'award']
# ['langja', 'hriges', 'mitglied', 'david', 'wheelers', 'experimental', 'theatre', 'company', 'boston', 'stand', 'richard', 'iii']
# ['bertolt', 'brechts', 'aufhaltsame', 'aufstieg', 'arturo', 'ui', 'bu', 'hne']
# ['new', 'york', 'london', 'spielte', 'pacino', 'david', 'mamets', 'american', 'buffalo', 'new', 'york', 'titelheld', 'richard', 'iii']
# ['spielte', 'mark', 'anton', 'julius', 'ca', 'sar']
# ['ausserdem', 'stand', 'square', 'theatre', 'new', 'york', 'oscar', 'wildes', 'salome', 'bu', 'hne', 'wirkte', 'urauffu', 'hrung', 'ira', 'levins', 'theaterstu', 'ck', 'chinese', 'coffee']
# ['theatersaison', 'spielte', 'pacino', 'shakespeare', 'the', 'park', 'produktion', 'kaufmann', 'venedig', 'shylock']
# ['inszenierung', 'gewann', 'heather', 'lind', 'shylocks', 'tochter', 'jessica', 'auftrat', 'theatre', 'world', 'award', 'fu', 'r', 'herausragendes', 'broadway', 'debu', 't']
# ['pacinos', 'erstes', 'eigensta', 'ndiges', 'projekt', 'looking', 'for', 'richard', 'dokumentarische', 'ku', 'nstlerische', 'filmstudie', 'u', 'ber', 'charakter', 'shakespeares', 'richard', 'iii']
# ['regie', 'fu', 'hrte', 'produktion', 'u', 'bernahm', 'drehbuch', 'schrieb', 'hauptrolle', 'spielte']
# ['pacino', 'produzent', 'hauptdarsteller', 'koautor', 'independent', 'kurzfilms', 'the', 'local', 'stigmatic', 'verfilmung', 'gleichnamigen', 'theaterstu', 'cks', 'heathcote', 'williams', 'sowohl', 'new', 'yorker', 'museum', 'of', 'modern', 'art', 'public', 'theatre', 'aufgefu', 'hrt', 'wurde']
# ['al', 'pacino', 'nie', 'verheiratet']
# ['drei', 'kinder', 'tochter', 'jan', 'tarrant', 'zwillinge', 'beverly', 'd', 'angelo']
# ['al', 'pacino', 'wurde', 'lauf', 'jahrzehnte', 'verschiedenen', 'deutschen', 'sprechern', 'synchronisiert']
# ['nachdem', 'ersten', 'jahrzehnt', 'karriere', 'regel', 'lutz', 'mackensy', 'gesprochen', 'wurde', 'u', 'bernahm', 'scarface', 'frank', 'glaubrecht', 'synchronisation', 'schauspielers']
# ['seit', 'glaubrecht', 'alleiniger', 'sprecher', 'mittlerweile', 'pacinos', 'standardstimme', 'bezeichnet']
# ['fru', 'hen', 'jahren', 'wurde', 'pacino', 'joachim', 'kammer', 'gottfried', 'kramer', 'klaus', 'kindler', 'gesprochen']
# ['name', 'alkalimetalle', 'leitet', 'arabischen', 'wort', 'fu', 'r', 'pottasche', 'ab', 'alte', 'bezeichnung', 'fu', 'r', 'pflanzenaschen', 'gewonnenes', 'kaliumcarbonat']
# ['humphry', 'davy', 'stellte', 'jahre', 'erstmals', 'element', 'kalium', 'schmelzflusselektrolyse', 'kaliumhydroxid', 'dar']
# ['letzteres', 'gewann', 'kaliumcarbonat']
# ['sprachen', 'spiegelt', 'namen', 'wider']
# ['heisst', 'kalium', 'beispielsweise', 'englischen', 'franzo', 'sischen', 'potassium', 'italienischen', 'potassio']
# ['alkalimetalle', 'metallisch', 'gla', 'nzende', 'silbrig', 'weisse', 'weiche', 'leichtmetalle']
# ['messer', 'schneidbar']
# ['alkalimetalle', 'geringe', 'dichte']
# ['reagieren', 'vielen', 'stoffen', 'beispielsweise', 'wasser', 'luft', 'halogenen', 'teilweise', 'a', 'usserst', 'heftig', 'starker', 'wa', 'rmeentwicklung']
# ['insbesondere', 'schwereren', 'alkalimetalle', 'ko', 'nnen', 'luft', 'entzu', 'nden']
# ['daher', 'schutzflu', 'ssigkeiten', 'paraffin', 'petroleum', 'bzw']
# ['luftabschluss', 'ampullen', 'aufbewahrt']
# ['elemente', 'ersten', 'gruppe', 'periodensystems', 'besitzen', 'schwach', 'gebundenes', 's', 'elektron', 'leicht', 'abgeben']
# ['ersten', 'ionisierungsenergien', 'elektronegativita', 'ten', 'entsprechend', 'klein']
# ['verbindungen', 'kommen', 'fast', 'ausschliesslich', 'einwertige', 'kationen', 'wenngleich', 'sogar', 'verbindungen', 'bekannt', 'denen', 'metalle', 'anionisch', 'vorliegen']
# ['alkalimetalle', 'salze', 'besitzen', 'spezifische', 'flammenfa', 'rbung', 'aufgrund', 'flammenfa', 'rbung', 'alkalimetallverbindungen', 'fu', 'r', 'feuerwerke', 'benutzt']
# ['atomphysik', 'alkalimetalle', 'eingesetzt', 'aufgrund', 'besonders', 'einfachen', 'elektronischen', 'struktur', 'besonders', 'leicht', 'lasern', 'ku', 'hlen', 'lassen']
# ['alkalimetalle', 'kristallisieren', 'kubisch', 'raumzentrierten', 'struktur']
# ['lediglich', 'lithium', 'natrium', 'kristallisieren', 'hexagonal', 'dichtesten', 'packung', 'tiefe', 'temperaturen', 'vorherrschen']
# ['radius', 'elementatome', 'sowie', 'kationen', 'nimmt', 'steigender', 'massenzahl']
# ['viele', 'eigenschaften', 'alkalimetalle', 'zeigen', 'trend', 'innerhalb', 'gruppe', 'oben', 'unten', 'alkalimetalle', 'reagieren', 'wasserstoff', 'bildung', 'salzartiger', 'alkalimetallhydride', 'thermische', 'besta', 'ndigkeit', 'hydride', 'nimmt', 'lithiumhydrid', 'caesiumhydrid', 'ab']
# ['alkalihydride', 'u', 'a', 'reduktions', 'trockenmittel', 'eingesetzt']
# ['sauerstoff', 'reagieren', 'metalle', 'bildung', 'fester', 'weisser', 'alkalimetalloxide', 'alkalimetallperoxide', 'alkalimetallhyperoxide', 'reaktion', 'wasser', 'alkalimetallhydroxiden', 'erfolgt', 'freisetzung', 'wasserstoff', 'lithium', 'caesium', 'steigt', 'reaktivita', 't', 'stark', 'ab', 'kalium', 'erfolgt', 'selbstentzu', 'ndung']
# ['hochgeschwindigkeitsaufnahmen', 'reaktion', 'alkalimetallen', 'wasser', 'legen', 'coulomb', 'explosion', 'nahe']
# ['alkalimetallhydroxide', 'farblose', 'feststoffe', 'wasser', 'starker', 'erwa', 'rmung', 'leicht', 'lo', 'sen', 'dabei', 'stark', 'basisch', 'reagieren']
# ['hydroxide', 'lo', 'sungen', 'wirken', 'stark', 'a', 'tzend']
# ['halogenen', 'reagieren', 'alkalimetalle', 'salzartigen', 'alkalimetallhalogeniden', 'reaktivita', 't', 'steigt', 'lithium', 'caesium', 'sinkt', 'fluor', 'iod']
# ['reagiert', 'natrium', 'iod', 'kaum', 'brom', 'langsam', 'wa', 'hrend', 'reaktion', 'kalium', 'brom', 'iod', 'explosionsartig', 'erfolgt']
# ['alkalimetalle', 'ko', 'nnen', 'halogenkohlenwasserstoffen', 'explosionserscheinungen', 'halogen', 'bildung', 'kohlenstoff', 'entsprechenden', 'alkalimetallhalogenid', 'entziehen', 'alkalimetalle', 'ergeben', 'flu', 'ssigem', 'ammoniak', 'intensiv', 'blau', 'gefa', 'rbte', 'lo', 'sungen']
# ['lo', 'sungen', 'positiven', 'alkalimetall', 'ionen', 'solvatisierten', 'elektronen', 'besteht', 'starkes', 'reduktionsmittel', 'beispielsweise', 'fu', 'r', 'birch', 'reduktion', 'eingesetzt']
# ['lo', 'sungen', 'geeigneter', 'komplexbildner', 'zugesetzt', 'ko', 'nnen', 'entsprechende', 'salze', 'alkalimetall', 'anionen', 'sogenannten', 'alkalide', 'bilden']
# ['wasserstoff', 'erste', 'element']
# ['hauptgruppe', 'normalbedingungen', 'nichtmetall']
# ['deshalb', 'alkalimetallen', 'geza', 'hlt', 'teilt', 'jedoch', 'eigenschaften']
# ['wasserstoff', 'tritt', 'alkalimetalle', 'stets', 'einwertig', 'wandelt', 'extrem', 'hohem', 'druck', 'metallische', 'hochdruckmodifikation', 'metallischen', 'wasserstoff']
# ['umgekehrt', 'alkalimetalle', 'bestimmten', 'bedingungen', 'eigenschaften', 'wasserstoff', 'z']
# ['b', 'besteht', 'lithium', 'gas', 'zweiatomigen', 'moleku', 'len']
# ['arbeit', 'bereits', 'seit', 'altertum', 'gegenstand', 'rechtlicher', 'regelungen']
# ['ro', 'mischen', 'recht', 'dienstvertrag', 'jedoch', 'aufgrund', 'verbreiteten', 'sklaven', 'arbeit', 'untergeordnete', 'rolle']
# ['deutschland', 'mittelalters', 'tragen', 'dienstverha', 'ltnisse', 'oft', 'personalrechtliche', 'ge']
# ['obgleich', 'bestimmten', 'gebieten', 'bereits', 'echte', 'kapitalisierung', 'arbeit', 'gibt', 'heute', 'verbreitung', 'kapitalistischen', 'verdinglichung', 'arbeit', 'ab', 'zweiten', 'ha', 'lfte']
# ['jahrhunderts', 'beginn', 'arbeitsrechtsgeschichte', 'angesehen']
# ['sozialen', 'misssta', 'nde', 'industrialisierung']
# ['jahrhundert', 'folge', 'privatautonomie', 'trotz', 'ungleichgewichtigkeit', 'macht', 'vertragspartner']
# ['erkennend', 'entwickelte', 'beispiel', 'jugendarbeitsschutz', 'verbot', 'kinderarbeit', 'sozialversicherungsrecht', 'sowie', 'abkehr', 'koalitionsverbot']
# ['entwicklung', 'trug', 'bu', 'rgerliche', 'gesetzbuch', 'jedoch', 'rechnung', 'dienstvertrag', 'ff']
# ['bgb', 'normaler', 'austauschvertrag', 'weitgehender', 'privatautonomie', 'geregelt', 'personenrechtliche', 'einschlag', 'arbeitsverha', 'ltnisses', 'wurde', 'anerkannt']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide
# Streaming output truncated to the last 5000 lines.
# ['februar', 'trat', 'gaviria', 'ministerposten', 'zuru', 'ck', 'wahlkampf', 'liberalen', 'pra', 'sidentschaftskandidaten', 'luis', 'carlos', 'gala', 'n', 'leiten']
# ['ermordung', 'popula', 'ren', 'politikers', 'korruption', 'drogenhandel', 'anka', 'mpfen']
# ['august', 'trat', 'gaviria', 'ebenfalls', 'linken', 'flu', 'gel', 'partei', 'zuzurechnen', 'nachfolge']
# ['pra', 'sidentschaftswahlen']
# ['august', 'setzte', 'gaviria', 'trujillo', 'stimmen', 'konservativen', 'kandidaten', 'a', 'lvaro', 'go', 'mez', 'hurtado', 'rodrigo', 'lloreda', 'caicedo', 'sowie', 'antonio', 'navarro', 'wolff', 'neu', 'gegru', 'ndeten', 'partei', 'alianza', 'democra', 'tica', 'm']
# ['zwei', 'weitere', 'linksgerichtete', 'kandidaten', 'carlos', 'pizarro', 'leo', 'n', 'go', 'mez', 'bernardo', 'jaramillo', 'ossa', 'wa', 'hrend', 'wahlkampfes', 'ermordet', 'worden']
# ['wa', 'hrend', 'regierung', 'gavirias', 'wurde', 'derzeit', 'geltende', 'kolumbianische', 'verfassung', 'verabschiedet', 'deren', 'ausarbeitung', 'erstmals', 'ehemalige', 'guerillaka', 'mpfer', 'sowie', 'vertreter', 'ethnischen', 'minderheiten', 'beteiligt']
# ['ausserdem', 'verschrieb', 'regierung', 'gavirias', 'kampf', 'drogenhandel', 'anbau', 'paramilita', 'rische', 'gruppierungen', 'guerillaorganisationen', 'farc', 'eln']
# ['verhandlungen', 'regierung', 'stellte']
# ['juni', 'drogenzar', 'pablo', 'escobar', 'kolumbianischen', 'beho', 'rden']
# ['regierung', 'gaviria', 'geriet', 'glaubwu', 'rdigkeitskrise', 'escobar', 'juli', 'gelang', 'gefa', 'ngniszelle', 'fliehen']
# ['zusa', 'tzlich', 'deckte', 'kolumbianische', 'presse', 'luxurio', 'sen', 'bedingungen', 'denen', 'escobar', 'haft', 'verbrachte']
# ['dezember', 'wurde', 'escobar', 'medelli', 'n', 'polizisten', 'erschossen']
# ['regierung', 'gaviria', 'setzte', 'grundlage', 'neuen', 'verfassung', 'reformen', 'sozialen', 'sicherung', 'arbeitsmarktes', 'ausserdem', 'versuchte', 'gaviria', 'hohe', 'inflation', 'stoppen', 'kolumbianische', 'wirtschaft', 'sta', 'rken']
# ['problem', 'unterversorgung', 'strom', 'lo', 'sen', 'fu', 'hrte', 'gaviria', 'trujillo', 'fu', 'r', 'eineinhalb', 'jahre', 'sogenannten', 'apago', 'n', 'zeitliche', 'beschra', 'nkung', 'verfu', 'gbarkeit', 'elektrischen', 'stroms']
# ['bereits', 'ende', 'pra', 'sidentschaft', 'august', 'wurde', 'gaviria', 'trujillo']
# ['ma', 'rz', 'stimmen', 'generalsekreta', 'r', 'organisation', 'amerikanischer', 'staaten', 'gewa', 'hlt', 'wurde', 'fu', 'r', 'zweite', 'periode', 'amt', 'besta', 'tigt']
# ['vermittelte', 'wa', 'hrend', 'politischen', 'krise', 'venezuela', 'regierung', 'cha', 'vez', 'opposition']
# ['ende', 'zweiten', 'amtszeit', 'jahr', 'gru', 'ndete', 'gaviria', 'trujillo', 'new', 'york', 'unternehmen', 'hemispheric', 'partners', 'beratungsfirma', 'fu', 'r', 'lateinamerika', 'ta', 'tige', 'unternehmen']
# ['seit', 'versta', 'rkte', 'gaviria', 'trujillo', 'aktivita', 'ten', 'liberalen', 'partei', 'kolumbiens']
# ['juni', 'wurde', 'parteichef', 'gewa', 'hlt', 'erkla', 'rte', 'ziel', 'zerstrittene', 'partei', 'pra', 'sidentschaftswahlen']
# ['vorfeld', 'abstimmung', 'kolumbianischen', 'volkes', 'friedensabkommen', 'havanna']
# ['oktober', 'u', 'bernimmt', 'ce', 'sar', 'gaviria', 'leitung', 'o', 'ffentlichen', 'kampagne', 'fu', 'r', 'zustimmung', 'friedensvertrag']
# ['gaviria', 'trujillo', 'mitglied', 'club', 'de', 'madrid']
# ['tv', 'serie', 'escobar', 'el', 'patro', 'n', 'del', 'mal', 'gaviria', 'kolumbianischen', 'schauspieler', 'fabian', 'mendoza', 'gespielt']
# ['fernsehserie', 'narcos', 'u', 'bernahm', 'mexikanische', 'schauspieler', 'rau', 'l', 'me', 'ndez', 'rolle', 'gaviria']
# ['ritter', 'sohn', 'verwaltungsangestellten', 'besuchte', 'zeitraum', 'zuna', 'chst', 'volks', 'danach', 'zwei', 'jahre', 'handelsschule', 'mittleren', 'reife', 'abschloss']
# ['anschliessend', 'berufsschule', 'lehrabschlusspru', 'fung', 'absolvierte']
# ['danach', 'anwa', 'rter', 'fu', 'r', 'gehobenen', 'dienst', 'stadtverwaltung', 'speyer', 'fand', 'ebenso', 'laufbahnpru', 'fung', 'statt']
# ['leitete', 'pensionierung', 'bauverwaltung', 'stadt', 'speyer']
# ['besuchte', 'neben', 'beruf', 'sieben', 'semester', 'lang', 'rheinland', 'pfa', 'lzische', 'verwaltungs', 'wirtschaftsakademie', 'erwarb', 'kommunal', 'diplom', 'wurde', 'diplom', 'verwaltungswirt']
# ['zurzeit', 'ritter', 'lehrauftrag', 'deutschen', 'universita', 't', 'fu', 'r', 'verwaltungswissenschaften', 'speyer']
# ['katholisch', 'seit', 'verheiratet', 'vater', 'zweier', 'inzwischen', 'erwachsener', 'kinder', 'lebt', 'ru', 'lzheim']
# ['hans', 'joachim', 'ritter', 'wurde', 'mitglied', 'jungen', 'union', 'mitglied', 'cdu', 'fu', 'r', 'ab', 'orts', 'verbandsgemeinderat', 'ru', 'lzheim', 'sass']
# ['beiden', 'gremien', 'geho', 'rte']
# ['wechselte', 'unu', 'berbru', 'ckbaren', 'differenzen', 'partei', 'umweltpolitik', 'jahr', 'zuvor', 'gegru', 'ndete', 'o', 'dp']
# ['zeitgleich', 'wurde', 'vorsitzender', 'neugegru', 'ndeten', 'kreisverband', 'speyer', 'germersheim']
# ['bereits', 'oktober', 'wurde', 'deren', 'landesvorsitzender', 'rheinland', 'pfalz']
# ['amt', 'fru', 'hjahr', 'inne']
# ['ritter', 'kandidierte', 'europawahl', 'platz', 'bundesliste', 'partei']
# ['parteitag', 'saarbru', 'cken', 'o', 'dp', 'gru', 'nder', 'herbert', 'gruhl', 'mehr', 'bundesvorsitzender', 'kandidiert']
# ['nachfolger', 'gespra', 'ch', 'ritter', 'hermann', 'bentele']
# ['wahl', 'fiel', 'ritter', 'delegierten', 'zugetraut', 'worden', 'vermittler', 'parteibasis', 'gruhl', 'fungieren']
# ['bereits', 'jahr', 'spa', 'ter', 'grenzte', 'ritter', 'bundesparteitag', 'wu', 'rzburg']
# ['januar', 'stattfand', 'unabha', 'ngigen', 'o', 'kologen', 'ab', 'rechten', 'gruppierung', 'ehemaliger', 'abtru', 'nniger', 'o', 'dp', 'mitglieder', 'gru', 'ndung', 'unabha', 'ngigen', 'o', 'kologen', 'deutschlands', 'beteiligte']
# ['gleichzeitig', 'drohte', 'parteimitgliedern', 'unabha', 'ngigen', 'o', 'kologen', 'zusammenarbeiteten', 'konsequenzen']
# ['o', 'dp', 'vorsitzender', 'fu', 'hrte', 'gespra', 'che', 'u', 'ber', 'zusammenarbeit', 'gru', 'nen', 'bu', 'ndnis']
# ['wa', 'hrend', 'teile', 'bu', 'ndnis', 'o', 'dp', 'aufgeschlossen', 'gegenu', 'berstanden', 'scheiterte', 'dreierbu', 'ndnis', 'westdeutschen', 'gru', 'nen']
# ['kreisrat', 'landkreis', 'germersheim', 'sowie', 'fraktionsvorsitzender', 'partei', 'wa', 'hrend', 'zeit', 'zwei', 'sitze', 'innehatte']
# ['koalition', 'spd', 'gru', 'ne', 'o', 'dp', 'ritter', 'ende', 'dritter', 'kreisdeputierter']
# ['koalition', 'scheiterte', 'jedoch', 'spa', 'ter', 'ritter', 'vereinbart', 'zweiten', 'beigeordneten', 'gewa', 'hlt', 'wurde']
# ['fu', 'hrung', 'gelang', 'o', 'dp', 'gewisse', 'konsolidierung', 'nachdem', 'jahren', 'ha', 'ufig', 'wegen', 'angeblich', 'mangelnder', 'abgrenzung', 'rechten', 'spektrum', 'kritisiert', 'worden']
# ['a', 'usserte', 'steigenden', 'mitgliederzahlen', 'partei', 'amtszeit']
# []
# ['september', 'gru', 'ndete', 'freiberg', 'stiftung', 'fu', 'r', 'o', 'kologie', 'demokratie', 'u', 'berparteilicher', 'tra', 'ger', 'politischen', 'bildung', 'deren', 'vorsitzender', 'seither', 'ununterbrochen']
# ['interessenskonflikte', 'neuen', 'ta', 'tigkeit', 'vermeiden', 'kandidierte', 'bundesparteitag']
# []
# ['juli', 'bottrop', 'mehr', 'fu', 'r', 'amt', 'o', 'dp', 'bundesvorsitzenden']
# ['nachfolger', 'amt', 'wurde', 'bernd', 'richter']
# ['jedoch', 'kandidierte', 'ritter', 'europawahl', 'deutschland', 'erneut', 'listenplatz', 'drei']
# ['ausserdem', 'vorsitzender', 'energieagentur', 'speyer', 'neustadt', 'su', 'dpfalz', 'projekt', 'stiftung', 'fu', 'r', 'o', 'kologie', 'demokratie', 'kuratoriumsmitglied', 'verbrauchervereinigung', 'medien', 'e', 'v']
# ['wurde', 'anla', 'sslich', 'ja', 'hrigen', 'jubila', 'ums', 'rheinland', 'pfa', 'lzischen', 'landesverbands', 'o', 'dp', 'fu', 'r', 'ja', 'hrige', 'mitgliedschaft', 'geehrt']
# ['wojciech', 'kossak', 'wurde']
# ['dezember', 'sohn', 'bekannten', 'polnischen', 'malers', 'juliusz', 'kossak', 'paris', 'geboren']
# ['ab']
# ['lebensjahr', 'bescha', 'ftigte', 'eingehend', 'malerei']
# ['studierte', 'dabei', 'krakau', 'mu', 'nchen', 'paris']
# ['ende']
# ['jahrhunderts', 'erlangte', 'erste', 'bekanntheit', 'schaffung', 'grosser', 'rundgema', 'lde', 'damals', 'modern']
# ['jahren', 'schuf', 'kossak', 'gemeinsam', 'jan', 'styka', 'malern', 'panorama', 'rac', 'awice', 'grosses', 'rundgema', 'lde', 'anla', 'sslich']
# ['jahrestages', 'kos', 'ciuszko', 'aufstandes', 'sieg', 'polnischen', 'truppen', 'schlacht', 'rac', 'awice', 'darstellte']
# ['werk', 'wurde', 'ku', 'nstlerischen', 'kommerziellen', 'erfolg', 'machte', 'kossak', 'weithin', 'bekannt']
# ['jahre', 'siedelte', 'berlin', 'u', 'ber', 'lebte']
# ['arbeitete', 'julian', 'fa', 'at', 'zuna', 'chst', 'gema', 'lde', 'u', 'berquerung', 'beresina', 'truppen', 'napoleons']
# ['april', 'erstmals', 'ausgestellt', 'wurde']
# ['heute', 'gema', 'lde', 'breslau', 'besichtigen']
# ['folgte', 'gema', 'lde', 'schlacht', 'fusse', 'pyramiden', 'zusammenarbeit', 'micha', 'wywio', 'rski']
# ['daneben', 'beta', 'tigte', 'kossak', 'erfolgreich', 'portra', 'tmaler', 'wobei', 'bilder', 'kaisern', 'franz', 'joseph', 'o', 'sterreich', 'ungarn', 'wilhelm', 'ii']
# ['schuf']
# ['letzterer', 'kossak', 'befreundet', 'meinte', 'sei', 'lieber', 'schneidiger', 'kerl', 'genialer', 'maler']
# ['gunst', 'deutschen', 'kaisers', 'brachte', 'kossak', 'weitere', 'auftra', 'ge', 'z']
# ['b', 'fu', 'r', 'grosse', 'gema', 'lde', 'angriff', 'garde', 'corps', 'schlacht', 'zorndorf']
# ['erhielt', 'grossen', 'berliner', 'kunstausstellung', 'kleine', 'goldmedaille']
# ['kossak', 'wurde', 'jahr', 'professor', 'kunstakademie', 'warschau', 'nahm', 'danach', 'ersten', 'weltkrieg', 'teil']
# ['kriegsmaler', 'k', 'u', 'k']
# ['kriegspressequartier', 'zugeteilt']
# ['krieg', 'kam', 'kontakt', 'einflussreichen', 'perso', 'nlichkeiten', 'marschall', 'ferdinand', 'foch', 'jo', 'zef', 'pi', 'sudski', 'portra', 'tierte']
# ['u', 'brigen', 'lebte', 'jahren', 'vereinigten', 'staaten']
# ['schwerpunkt', 'arbeiten', 'bildeten', 'ersten', 'weltkrieg', 'verschiedenen', 'themen', 'polnischen', 'geschichte', 'zeitgeschichte']
# ['starb']
# ['juli', 'krakau']
# ['nachkommen', 'kossaks', 'erreichten', 'gro', 'ssere', 'bekanntheit']
# ['wurde', 'sohn', 'jerzy', 'kossak', 'ebenfalls', 'maler', 'to', 'chter', 'maria', 'pawlikowska', 'jasnorzewska', 'magdalena', 'samozwaniec', 'bekannte', 'schriftstellerinnen']
# ['nichte', 'kossak', 'szczucka', 'tochter', 'zwillingsbruders', 'tadeusz', 'kossak', 'ebenfalls', 'schriftstellerin', 'bedeutende', 'polnische', 'widerstandska', 'mpferin']
# ['kreis', 'schleiden', 'grenzte', 'uhrzeigersinn', 'nordwesten', 'beginnend', 'kreise', 'monschau', 'ren', 'euskirchen', 'sowie', 'landkreise', 'ahrweiler', 'daun', 'bitburg', 'pru', 'm']
# ['westen', 'grenzte', 'belgische', 'provinz', 'lu', 'ttich']
# ['kreis', 'schleiden', 'ging', 'kreis', 'gemu', 'nd', 'hervor', 'neuordnung', 'preussischen', 'rheinprovinzen', 'regierungsbezirk', 'aachen', 'eingerichtet', 'worden']
# ['wurde', 'kreis', 'schleiden', 'umbenannt', 'nachdem', 'landratssitz', 'schleiden', 'verlegt', 'worden']
# ['kreis', 'schleiden', 'setzte', 'anfa', 'nglich', 'bu', 'rgermeistereien', 'blankenheim', 'bleibuir', 'dollendorf', 'dreiborn', 'eicks', 'gemu', 'nd', 'heimbach', 'hellenthal', 'hollerath', 'holzmu', 'lheim', 'kall', 'keldenich', 'kronenburg', 'lommersdorf', 'marmagen', 'no', 'then', 'schleiden', 'tondorf', 'udenbreth', 'vussem', 'wahlen', 'wallenthal', 'weyer', 'zusammen']
# ['bu', 'rgermeistereien', 'holzmu', 'lheim', 'tondorf', 'wurden', 'spa', 'ter', 'gemeinsamen', 'bu', 'rgermeisterei', 'zusammengeschlossen']
# ['einfu', 'hrung', 'gemeindeordnung', 'fu', 'r', 'rheinprovinz', 'wurden', 'meisten', 'bu', 'rgermeistereien', 'kreises', 'mehrere', 'gemeinden', 'untergliedert']
# ['gemu', 'nd', 'erhielt', 'schleiden', 'rheinische', 'sta', 'dteordnung']
# ['dahin', 'bu', 'rgermeisterei', 'schleiden', 'geho', 'renden', 'gemeinden', 'broich', 'bronsfeld', 'harperscheid', 'oberhausen', 'scho', 'neseiffen', 'bildeten', 'seitdem', 'bu', 'rgermeisterei', 'harperscheid']
# ['kreis', 'schleiden', 'bestanden', 'seitdem', 'fla', 'che', 'km', 'bu', 'rgermeistereien', 'insgesamt', 'gemeinden', 'bu', 'rgermeisterei', 'vussem', 'wurde', 'bu', 'rgermeisterei', 'mechernich', 'umbenannt']
# ['gemeinden', 'strempt', 'roggendorf', 'wurden', 'gemeinde', 'mechernich', 'eingegliedert']
# ['ersten', 'weltkrieg', 'wurde', 'gemeinde', 'losheim', 'kreis', 'schleiden', 'eingegliedert']
# ['losheim', 'teil', 'kreises', 'malmedy', 'belgien', 'gefallen', 'kehrte', 'nachverhandlungen', 'deutsche', 'reich', 'zuru', 'ck']
# ['gesamten', 'rheinprovinz', 'wurden', 'seit']
# ['januar', 'bu', 'rgermeistereien', 'kreises', 'a', 'mter', 'bezeichnet']
# ['jahren', 'wurden', 'gemeinden', 'frohnrath', 'heistert', 'gemeinde', 'sistig', 'eingegliedert']
# ['ausserdem', 'wurden', 'beiden', 'tenicher', 'teilgemeinden', 'gemeinde', 'rinnen', 'gemeinde', 'tenich', 'zusammengeschlossen']
# []
# ['april']
# ['august', 'geho', 'rte', 'losheim', 'belgien', 'basis', 'deutsch', 'belgischen', 'grenzvertrages', 'deutschland', 'kreis', 'schleiden', 'zuru', 'ckkehrte']
# ['jahren', 'wurde', 'zahl', 'a', 'mter', 'kreises', 'mehrfach', 'reduziert', 'wurden', 'a', 'mter', 'bleibuir', 'eicks', 'jahre', 'neuen', 'amt', 'hergarten', 'zusammengeschlossen']
# []
# ['april', 'wurden', 'heimbach', 'stadtrechte', 'verliehen']
# ['landkreis', 'schleiden', 'bestanden', 'neun', 'a', 'mter', 'insgesamt', 'gemeinden', 'rahmen', 'nordrhein', 'westfa', 'lischen', 'gebietsreform', 'wurden', 'zuna', 'chst']
# ['juli', 'heimbach', 'hausen', 'neuen', 'gro', 'sseren', 'stadt', 'heimbach', 'zusammengeschlossen']
# ['gleichzeitig', 'wurde', 'amt', 'heimbach', 'aufgelo', 'st']
# []
# ['juli', 'trat', 'gesetz', 'neugliederung', 'gemeinden', 'landkreises', 'schleiden', 'kraft', 'gleichzeitig', 'schieden', 'gesetz', 'neugliederung', 'landkreises', 'euskirchen', 'hohn', 'no', 'then', 'landkreis', 'schleiden', 'wurden', 'teil', 'stadt', 'bad', 'mu', 'nstereifel', 'kreis', 'euskirchen']
# []
# ['oktober', 'wurde', 'landkreis', 'schleiden', 'sta', 'dte', 'gemeinden', 'umfasste', 'kreis', 'schleiden']
# ['aachen', 'gesetz', 'brachte']
# ['januar', 'weitere', 'gemeindezusammenschlu', 'sse', 'ende', 'kreises', 'schleiden', 'zusta', 'ndige', 'milita', 'rdienststelle', 'viii']
# ['armeekorps', 'zusta', 'ndige', 'gerichte', 'amtsgericht', 'blankenheim', 'landgericht', 'aachen', 'oberlandesgericht', 'ko', 'ln', 'sowie', 'spa', 'ter', 'unteren', 'instanz', 'amtsgericht', 'gemu', 'nd']
# ['zusta', 'ndige', 'finanza', 'mter', 'seit', 'finanzamt', 'gemu', 'nd', 'landesfinanzamt', 'ko', 'ln']
# ['geho', 'rte', 'kreis', 'schleiden', 'nsdap', 'gau', 'ko', 'ln', 'aachen']
# ['evangelische', 'kirche', 'kreis', 'schleiden', 'geho', 'rte', 'altpreussischen', 'union', 'kirchenprovinz', 'rheinland', 'katholischen', 'einrichtungen', 'erzbistum', 'ko', 'ln', 'seit', 'zweiter', 'gru', 'ndung', 'bistums', 'aachen', 'hierzu']
# ['liste', 'parteien', 'wa', 'hlergemeinschaften', 'aufgefu', 'hrt', 'mindestens', 'zwei', 'prozent', 'stimmen', 'jeweiligen', 'wahl', 'erhalten']
# ['hinweis', 'kreis', 'wies', 'wahl', 'recht', 'hohen', 'stimmenanteil', 'fu', 'r', 'unabha', 'ngige', 'kandidaten']
# ['stimmenanteile', 'parteien', 'prozent', 'wahl', 'jahr', 'erreichten', 'unabha', 'ngige', 'kandidaten', 'gu', 'ltigen', 'stimmen']
# []
# ['preussischen', 'staat', 'wurden', 'landra', 'te', 'regierung', 'ernannt']
# ['erster', 'gewa', 'hlter', 'landrat', 'kreises', 'schleiden', 'wurde', 'peter', 'lauterbach']
# []
# ['juli', 'wurde', 'damaligen', 'landkreis', 'einfu', 'hrung', 'heute', 'gu', 'ltigen', 'kfz', 'kennzeichen', 'unterscheidungszeichen', 'sle', 'zugewiesen']
# ['wurde']
# ['dezember', 'ausgegeben']
# ['seit']
# ['februar', 'kreis', 'euskirchen', 'seit']
# ['juli', 'kreis', 'ren', 'erha', 'ltlich']
# ['andrei', 'wyschinski', 'sohn', 'hohen', 'zaristischen', 'beamten', 'polnisch', 'katholischer', 'herkunft']
# ['schloss', 'menschewiki', 'sozialdemokratischen', 'arbeiterpartei', 'russlands']
# ['studierte', 'kiewer', 'universita', 't', 'rechtswissenschaften', 'danach', 'wurde', 'wissenschaftlicher', 'mitarbeiter', 'doktorand', 'eingestellt', 'allerdings', 'wegen', 'politischen', 'ansichten', 'stadt', 'anweisung', 'zaristischen', 'polizei', 'verlassen']
# ['februarrevolution', 'bekleidete', 'fu', 'r', 'wenige', 'monate', 'posten', 'leiters', 'miliz', 'moskauer', 'stadtbezirks', 'samoskworetschje']
# ['funktion', 'zeichnete', 'haftbefehl', 'lenin', 'grigori', 'sinowjew', 'kerenski', 'regierung', 'erlassen', 'wurde']
# ['erst', 'trat', 'wyschinski', 'kp']
# ['gewann', 'rasch', 'vertrauen', 'stalins', 'bereits', 'wa', 'hrend', 'zarenzeit', 'gefa', 'ngnis', 'getroffen', 'machte', 'karriere', 'dozent', 'rechtstheoretiker']
# ['staatsanwalt', 'beim', 'obersten', 'gericht', 'sowjetunion', 'wechselte', 'wissenschaft']
# ['rektor', 'moskauer', 'staatsuniversita', 't', 'bedeutender', 'posten', 'innerhalb', 'sowjetischen', 'hochschulsystems', 'mitglied', 'kollegiums', 'volkskommissariats', 'fu', 'r', 'bildungswesen']
# ['jahr', 'richter', 'schachty', 'prozess', 'fungiert']
# ['staatsanwalt', 'rsfsr', 'stellvertretender', 'volkskommissar', 'justiz', 'rsfsr', 'ab', 'stellvertretender', 'staatsanwalt', 'sowjetunion']
# ['geho', 'rte', 'leitern', 'staatsanwaltschaftlichen', 'ermittlungen', 'ermordung', 'leningrader', 'parteifu', 'hrers', 'sergej', 'kirow']
# ['folter', 'erbrachte', 'untersuchung', 'stalin', 'gewu', 'nschte', 'ergebnis']
# ['wyschinski', 'generalstaatsanwalt', 'sowjetunion']
# ['enger', 'absprache', 'stalin', 'entwarf', 'drehbu', 'cher', 'fu', 'r', 'schauprozesse', 'wobei', 'angeklagten', 'meist', 'schwere', 'folter', 'aussagen', 'erwu', 'nschten', 'gesta', 'ndnissen', 'gebracht', 'wurden']
# ['auftritten', 'schrie', 'angeklagten', 'oft', 'verwendete', 'ordina', 're', 'schimpfwo', 'rter', 'fu', 'r']
# ['wyschinski', 'gelegentlich', 'vollstreckung', 'beantragten', 'todesurteile', 'perso', 'nlich', 'anwesend', 'etwa', 'nkwd', 'henker', 'wassili', 'blochin', 'marschall', 'michail', 'tuchatschewski', 'genickschuss', 'to', 'tete']
# ['zeit', 'spa', 'ter', 'wa', 'hrend', 'leiter', 'rechtsinstituts', 'akademie', 'wissenschaften', 'udssr', 'fungierte', 'vertrat', 'grundsatz', 'recht', 'ausdruck', 'willens', 'herrschenden', 'klasse', 'sei']
# ['augen', 'reichten', 'gesta', 'ndnisse', 'angeklagten', 'schuld', 'dokumentieren', 'seien', 'wichtigsten', 'beweismittel']
# ['wurde', 'mitglied', 'zentralkomitees', 'stellvertretender', 'vorsitzender', 'rats', 'volkskommissare', 'ab', 'gleichzeitig', 'erste', 'stellvertreter', 'volkskommissars', 'fu', 'r', 'a', 'usseren', 'angelegenheiten', 'wjatscheslaw', 'molotow']
# ['juni', 'wurde', 'beauftragter', 'sowjetischen', 'regierung', 'lettland', 'entsandt', 'folge', 'gefa', 'lschten', 'wahlen', 'sowjetunion', 'annektiert', 'wurde']
# ['unmittelbar', 'kriegsende', 'bekam', 'auftrag', 'drehbuch', 'fu', 'r', 'moskauer', 'prozess', 'sechzehn', 'entwerfen', 'angeklagt', 'polnische', 'politiker', 'hohe', 'milita', 'rs', 'sowjetisierung', 'heimatlandes', 'stellten']
# ['anschliessend', 'leitete', 'regierungskommission', 'kulissen', 'sowjetische', 'juristendelegation', 'fu', 'r', 'nu', 'rnberger', 'prozesse', 'vorbereitete']
# ['geho', 'rte', 'pra', 'parierung', 'angeblicher', 'zeugen', 'massakers', 'katyn', 'besta', 'tigen', 'sollten', 'deutsches', 'verbrechen', 'handelte']
# []
# ['ma', 'rz', 'u', 'bernahm', 'nachfolger', 'molotows', 'posten', 'aussenministers', 'sowjetunion']
# ['tod', 'stalins', 'verdra', 'ngte', 'molotow', 'posten', 'schob', 'botschafter', 'vereinten', 'nationen', 'new', 'york', 'ab']
# ['wyschinski', 'starb', 'new', 'york']
# ['urne', 'wurde', 'kremlmauer', 'moskau', 'beigesetzt']
# ['paris', 'erscheinende', 'russische', 'emigrantenzeitung', 'russkaja', 'mysl', 'berichtete', 'damals', 'berufung', 'quellen', 'cia', 'wyschinski', 'sei', 'eigens', 'moskau', 'angereisten', 'agenten', 'vergiftet', 'worden', 'sei', 'opfer', 'machtkampfes', 'stalins', 'tod', 'geworden']
# ['generalstaatsanwaltschaft', 'russischen', 'fo', 'deration', 'gab', 'webseite', 'selbstmord', 'begangen']
# ['autor', 'insgesamt', 'fast', 'publikationen', 'seit', 'mitglied', 'akademie', 'wissenschaften', 'udssr']
# ['arbeit', 'theorie', 'beweisfu', 'hrung', 'beim', 'gericht', 'sowjetischen', 'recht', 'politische', 'repressionen', 'theoretisch', 'rechtfertigt', 'bekam', 'stalinpreis', 'erster', 'klasse', 'verliehen']
# ['wyschinski', 'wurde', 'viermal', 'leninorden', 'ausgezeichnet']
# ['reden', 'wa', 'hrend', 'moskauer', 'schauprozesse', 'dienten', 'ddr', 'diskussionsgrundlage', 'schulungsmaterial']
# ['wu', 'rden', 'justizministerin', 'hilde', 'benjamin', 'grundlegende', 'erkenntnisse', 'theorie', 'staates', 'rechtes', 'staats', 'rechtspraxis', 'vermitteln']
# ['hintergrund', 'wurde', 'strafprozessordnung', 'ddr', 'entwickelt']
# []
# ['november', 'wurde', 'gedenkfeier', 'vereinigung', 'demokratischer', 'juristen', 'wirken', 'wyschinskis', 'ministerium', 'justiz', 'ausdru', 'cklich', 'gewu', 'rdigt']
# ['belisario', 'betancur', 'wurde']
# ['februar', 'sohn', 'rosendo', 'betancur', 'ana', 'otilia', 'cuartas', 'kolumbianischen', 'amaga', 'geboren']
# ['studierte', 'rechts', 'wirtschaftswissenschaft', 'pa', 'pstlichen', 'universita', 't', 'bolivariana', 'medelli', 'n', 'u', 'ber', 'o', 'ffentliche', 'wirtschaftsordnung', 'promovierte']
# ['promotion', 'arbeitete', 'betancur', 'journalist', 'fu', 'r', 'mehrere', 'kolumbianische', 'tages', 'wochenzeitungen', 'ausserdem', 'schrieb', 'bu', 'cher', 'wirtschaftlichen', 'politischen', 'linguistischen', 'soziologischen', 'themen', 'gru', 'ndete', 'verlag', 'editorial', 'tercer', 'mundo']
# ['betancur', 'ehrendoktor', 'universita', 'ten', 'colorado', 'washington']
# ['gru', 'ndete', 'betancur', 'nationale', 'vereinigung', 'finanzinstitute', 'jahr', 'lang', 'vorstand']
# ['heiratete', 'belisario', 'betancur', 'rosa', 'helena', 'alvarez', 'mittlerweile', 'verstorben', 'drei', 'kinder', 'beatriz', 'diego', 'mari', 'a', 'clara']
# ['begann', 'belisario', 'betancur', 'politische', 'karriere', 'abgeordneter', 'konservativen', 'partei', 'kolumbiens', 'partido', 'conservador', 'colombiano', 'regionalparlament', 'antioquia']
# ['wurde', 'fu', 'r', 'provinz', 'cundinamarca', 'abgeordnetenhaus', 'gewa', 'hlt']
# ['wa', 'hrend', 'regierungszeit', 'diktators', 'gustavo', 'rojas', 'pinilla', 'betancur', 'mitglied', 'verfassunggebenden', 'versammlung']
# ['bestritt', 'rechtma', 'ssigkeit', 'pra', 'sidentschaft', 'rojas', 'pinillas', 'setzte', 'fu', 'r', 'konservativen', 'politiker', 'laureano', 'go', 'mez', 'gefa', 'ngnisaufenthalt', 'einbrachte']
# ['ende', 'milita', 'rdiktatur', 'rojas', 'pinillas', 'setzte', 'betancur', 'politische', 'karriere', 'fort']
# ['wurde', 'arbeitsminister', 'regierung', 'guillermo', 'leo', 'n', 'valencias', 'kolumbianischer', 'botschafter', 'spanien']
# ['pra', 'sidentschaftswahlen', 'kandidierte', 'betancur', 'erfolglos']
# ['mai', 'wurde', 'schliesslich', 'pra', 'sidenten', 'kolumbiens', 'gewa', 'hlt']
# ['wa', 'hrend', 'amtszeit', 'pra', 'sident', 'setzte', 'betancur', 'fu', 'r', 'friedensverhandlungen', 'unterschiedlichen', 'akteuren', 'kolumbianischen', 'konflikts', 'verhandelte', 'wichtigsten', 'guerillagruppen', 'farc', 'eln', 'epl', 'friedensabkommen']
# []
# ...
# ['ryan', 'phillippe', 'feierte', 'film', 'spielfilmdebu', 't']
# ['name', 'lt', 'zimmer', 'wurde', 'hommage', 'hans', 'zimmer', 'gewa', 'hlt', 'fu', 'r', 'soundtrack', 'verantwortlich', 'zeichnete']
# ['filmset', 'fu', 'r', 'bru', 'cke', 'uss', 'alabama', 'verwendet', 'wurde', 'spa', 'ter', 'film', 'independence', 'day', 'fu', 'r', 'aufnahmen', 'uss', 'georgia', 'sehen']
# ['weiterhin', 'wurde', 'uss', 'barbel', 'fu', 'r', 'aufnahmen', 'genutzt', 'denen', 'besatzung', 'u', 'bootes', 'dock', 'aufstellung', 'fu', 'r', 'ansprache', 'kommandanten', 'nimmt']
# ['aufnahmen', 'u', 'boot', 'erstmals', 'tauchgang', 'geht', 'zeigen', 'reale', 'uss', 'alabama']
# ['tony', 'scott', 'folgte', 'u', 'boot', 'helikopter', 'nahm', 'filmaufnahmen', 'befehlshaber', 'schiffs', 'befehl', 'abtauchen', 'gab', 'nachdem', 'filmcrew', 'anweisungen', 'einstellung', 'aufnahmen', 'folge', 'leistete']
# ['simpsons', 'folge', 'homer', 'geht', 'marine', 'gibt', 'mehrere', 'anspielungen', 'crimson', 'tide']
# ['lautet', 'englische', 'originaltitel', 'simpson', 'tide', 'wurde', 'ansprache', 'kapita', 'ns', 'besatzung', 'detailgetreu', 'u', 'bernommen']
# ['rahmen', 'untersuchungsausschuss', 'verhandlung', 'homer', 'simpson', 'erinnert', 'abschliessende', 'anho', 'rung', 'originals']
# ['hunter', 'techniker', 'vossler', 'spricht', 'bittet', 'funkgera', 't', 'schnellstens', 'reparieren', 'erwa', 'hnt', 'dritten', 'star', 'trek', 'kinofilm', 'klingonisches', 'schiff', 'enterprise', 'angreift', 'chefingenieur', 'scotty', 'captain', 'kirk', 'gebeten', 'warp', 'antrieb', 'schnellstens', 'reparieren']
# ['spa', 'ter', 'film', 'zitiert', 'hunter', 'nochmals', 'captain', 'kirk']
# ['film', 'diskutierte', 'herkunft', 'lipizzaner', 'pferde', 'weder', 'spanien', 'portugal', 'lipica', 'heutigen', 'slowenien']
# ['zeit', 'gru', 'ndung', 'gestu', 'ts', 'lag', 'lipica', 'o', 'sterreichischen', 'teil', 'habsburgerreiches']
# ['titelname', 'crimson', 'tide', 'anspielung', 'namen', 'spielenden', 'sportmannschaften', 'universita', 't', 'alabama', 'u', 'boot', 'namen', 'uss', 'alabama', 'tra', 'gt']
# ['ansonsten', 'bedeutet', 'purpurrote', 'gezeiten']
# ['deutschsprachige', 'synchronisation', 'films', 'erfolgte', 'magma', 'synchron', 'gmbh', 'berlin', 'dialogbuch', 'sowie', 'dialogregie', 'joachim', 'kunzendorf']
# ['chris', 'lebenzon', 'wurde', 'fu', 'r', 'besten', 'schnitt', 'fu', 'r', 'filmpreis', 'academy', 'award', 'nominiert']
# ['weitere', 'oscar', 'nominierungen', 'gab', 'fu', 'r', 'besten', 'ton', 'fu', 'r', 'besten', 'toneffekte']
# ['hans', 'zimmer', 'wurde', 'fu', 'r', 'filmmusik', 'fu', 'r', 'saturn', 'award', 'nominiert', 'gewann', 'grammy', 'award']
# ['denzel', 'washington', 'wurde', 'fu', 'r', 'rolle', 'fu', 'r', 'mtv', 'movie', 'award', 'nominiert', 'gewann', 'image', 'award']
# ['wurde', 'hochschule', 'fu', 'r', 'maschinenbau', 'elektrotechnik', 'hochschuleinrichtung', 'tschechischen', 'technischen', 'universita', 't', 'prag', 'gegru', 'ndet']
# ['wurde', 'eigensta', 'ndige', 'hochschule', 'abgegliedert', 'zwei', 'fakulta', 'ten', 'geteilt']
# ['jahre', 'entstanden', 'fakulta', 'ten', 'fu', 'r', 'o', 'konomie', 'angewandte', 'wissenschaften']
# ['pa', 'dagogische', 'fakulta', 't', 'wurde', 'zweigstelle', 'pa', 'dagogischen', 'fakulta', 't', 'karls', 'universita', 't', 'prag', 'gegru', 'ndet']
# ['ab', 'bestand', 'unabha', 'ngig', 'ho', 'here', 'pa', 'dagogische', 'schule', 'spa', 'ter', 'pa', 'dagogisches', 'institut']
# ['ab', 'unabha', 'ngige', 'fakulta', 't']
# ['jahre', 'wurden', 'beide', 'hochschulen', 'gesetz', 'nr']
# ['sb']
# ['westbo', 'hmischen', 'universita', 't', 'zusammengeschlossen']
# ['entstand', 'juristische', 'fakulta', 't', 'philosophische', 'fakulta', 't']
# ['trat', 'private', 'hochschule', 'pilsen', 'universita', 't', 'wurde', 'fakulta', 't', 'fu', 'r', 'gesundheitswissenschaften', 'integriert']
# ['institut', 'fu', 'r', 'kunst', 'design', 'wurde', 'neunten', 'fakulta', 't']
# ['fakulta', 'ten', 'institute', 'zentren', 'fakulta', 'tszugeho', 'rigkeit', 'weitere', 'einrichtungen']
# ['verliess', 'mbwando', 'heimat', 'simbabwe', 'bekam', 'beim', 'polnischen', 'erstligisten', 'lech', 'posen']
# ['profivertrag']
# ['kam', 'deutschland', 'spielte', 'fu', 'nf', 'jahre', 'lang', 'fu', 'r', 'verschiedene', 'vereine', 'damals', 'drittklassigen', 'regionalligen', 'halbprofi', 'liga', 'bezeichnet', 'ko', 'nnen']
# ['stieg', 'stammspieler', 'vfb', 'lu', 'beck']
# ['bundesliga', 'wechselte', 'ligakonkurrenten', 'alemannia', 'aachen']
# ['konnte']
# ['station', 'profifussball', 'gro', 'ssten', 'erfolge', 'feiern']
# ['wurde', 'alemannia', 'herbstmeister', 'verpasste', 'erst', 'letzten', 'spieltag', 'anvisierten', 'aufstieg', 'bundesliga']
# ['schliesslich', 'stand', 'letzten', 'profispiel', 'alemannias', 'startelf', 'beim', 'pokalfinale', 'frisch', 'geku', 'rten', 'deutschen', 'meister', 'werder', 'bremen']
# []
# ['minute', 'endete', 'mbwandos', 'zeit', 'alemannia', 'aachen', 'sowie', 'deutschen', 'profifussball']
# ['aachen', 'verlor']
# ['folgenden', 'saison', 'wechselte', 'mbwando', 'damaligen', 'regionalligisten', 'ssv', 'jahn', 'regensburg', 'mittelfeld', 'abwehr', 'eingesetzt', 'wurde']
# ['abstieg', 'zeit', 'viertklassige', 'bayernliga', 'unterschrieb', 'beim', 'fc', 'ingolstadt']
# ['saison', 'wurde', 'spielertrainer', 'beim', 'fc', 'bo', 'hmfeld', 'oberbayerischen', 'landkreis', 'eichsta', 'tt']
# ['ersten', 'saison', 'feierte', 'aufstieg', 'fussball', 'a', 'klasse', 'donau', 'isar', 'kreisklasse']
# ['mbwando', 'geho', 'rte', 'kader', 'nationalmannschaft', 'simbabwe', 'fu', 'r', 'elf', 'spiele', 'absolvierte', 'tor', 'schoss']
# ['carroll', 'begann', 'motorsportkarriere', 'kartsport', 'sportart', 'aktiv']
# ['debu', 'tierte', 'formelsport', 'fuhr', 'franzo', 'sischen', 'formel', 'renault', 'campus', 'winterserie', 'formel', 'palmer', 'audi']
# ['wechselte', 'britische', 'formel', 'ford']
# ['siebten', 'platz', 'hauptserie', 'gewann', 'wintermeisterschaft']
# ['trat', 'abermals', 'britischen', 'formel', 'ford', 'wurde', 'sieg', 'zehnter']
# ['wechselte', 'carroll', 'sweeney', 'racing', 'britische', 'formel', 'meisterschaft']
# ['gewann', 'ha', 'lfte', 'rennen', 'b', 'wertung', 'sicherte', 'meistertitel', 'b', 'klasse']
# ['bestes', 'resultat', 'zweiter', 'platz', 'diverse', 'fahrer', 'a', 'klasse', 'liess']
# ['fuhr', 'carroll', 'fu', 'r', 'drei', 'verschiedene', 'teams', 'britischen', 'formel', 'meisterschaft', 'trat', 'acht', 'zwo', 'lf', 'rennwochenenden']
# ['drei', 'zweiten', 'pla', 'tzen', 'beste', 'resultate', 'belegte', 'zehnten', 'gesamtrang']
# ['ausserdem', 'startete', 'letzten', 'vier', 'rennwochenenden', 'formel', 'euroserie', 'wurde']
# ['gesamtklassement']
# ['erhielt', 'carroll', 'p', 'racing', 'cockpit', 'fu', 'r', 'komplette', 'saison', 'britischen', 'formel', 'meisterschaft']
# ['gewann', 'fu', 'nf', 'rennen', 'wurde', 'nelson', 'piquet', 'jr', 'vizemeister']
# ['zudem', 'nahm', 'formel', 'testfahrten', 'fu', 'r', 'british', 'american', 'racing', 'teil']
# ['wechselte', 'carroll', 'gp', 'serie']
# ['ersetzte', 'kurz', 'saisonauftakt', 'hayanari', 'shimoda', 'super', 'nova', 'racing', 'teamkollege', 'giorgio', 'pantano', 'jahr', 'zuvor', 'formel', 'gestartet', 'wurde']
# ['carroll', 'gewann', 'drei', 'rennen', 'prestigetra', 'chtige', 'rennen', 'monte', 'carlo', 'beendete', 'saison', 'platz', 'pantano', 'fu', 'nften', 'rang', 'fahrerwertung']
# ['ausserdem', 'absolvierte', 'erneut', 'formel', 'testfahrten', 'fu', 'r', 'british', 'american', 'racing']
# ['ging', 'carroll', 'fu', 'r', 'racing', 'engineering', 'start']
# ['sieg', 'blieb', 'saison', 'verwehrt', 'erzielte', 'vier', 'podest', 'platzierungen']
# ['ende', 'saison', 'belegte', 'achten', 'gesamtrang']
# ['teamkollegen', 'javier', 'villa', 'punkte', 'erzielte', 'distanzierte', 'dabei', 'deutlich']
# ['verliess', 'carroll', 'zuna', 'chst', 'formelsport', 'startete', 'dtm', 'zwei', 'jahre', 'alten', 'audi', 'a', 'dtm', 'fu', 'r', 'team', 'futurecom', 'tme']
# ['neunten', 'platz', 'bestes', 'resultat', 'blieben', 'punkte', 'verwehrt']
# ['fu', 'nf', 'rennen', 'wurde', 'markus', 'winkelhock', 'ersetzt']
# ['carroll', 'kehrte', 'umgehend', 'gp', 'serie', 'zuru', 'ck', 'ersetzte', 'antonio', 'pizzonia', 'fms', 'international']
# ['wa', 'hrend', 'teamkollege', 'jason', 'tahinciog', 'lu', 'punkte', 'blieb', 'gewann', 'carroll', 'zwei', 'rennen', 'beendete', 'saison', 'siebten', 'platz', 'gesamtklassement']
# ['obwohl', 'carroll', 'brite', 'startete', 'winter', 'fu', 'r', 'irische', 'team', 'a', 'gp']
# ['ersetzte', 'rennwochenende', 'ralph', 'firman', 'gewann', 'rennen']
# ['irische', 'team', 'belegte', 'ende', 'saison', 'sechsten', 'platz', 'meisterschaft']
# ['sommer', 'kehrte', 'fu', 'r', 'zwei', 'rennwochenenden', 'gp', 'serie', 'zuru', 'ck']
# ['ehemaliges', 'team', 'fms', 'international', 'beno', 'tigte', 'kurzfristig', 'ersatz', 'fu', 'r', 'adria', 'n', 'valle', 's']
# ['vierten', 'rennwochenende', 'wurde', 'marko', 'asmer', 'ersetzt']
# ['gesamtwertung', 'belegte', 'carroll']
# ['platz']
# ['winter', 'startete', 'erneut', 'a', 'gp', 'serie', 'trat', 'fu', 'r', 'irische', 'mannschaft']
# ['carroll', 'gewann', 'fu', 'nf', 'rennen', 'sicherte', 'team', 'einziger', 'pilot', 'meistertitel']
# ['a', 'gp', 'stellte', 'rennbetrieb', 'saison']
# ['folgenden', 'sommersaison', 'carroll', 'cockpit']
# ['debu', 'tierte', 'carroll', 'nordamerikanischen', 'indycar', 'series', 'trat', 'fu', 'r', 'andretti', 'autosport', 'zwei', 'rennen']
# ['gesamtwertung', 'belegte']
# ['platz']
# ['carroll', 'zuna', 'chst', 'erneut', 'cockpit']
# ['jahresmitte', 'kehrte', 'allerdings', 'guten', 'leistungen', 'europa', 'ischen', 'motorsport', 'zuru', 'ck']
# ['zuna', 'chst', 'kehrte', 'p', 'motorsport', 'zuru', 'ck', 'nahm', 'rennwochenende', 'formel', 'renault', 'teil']
# ['mo', 'glichkeit', 'ergab', 'stammpilot', 'walter', 'grubmu', 'ller', 'verletzungsbedingt', 'pausieren']
# ['carroll', 'kam', 'anhieb', 'zurecht', 'erzielte', 'vierten', 'dritten', 'platz']
# ['wegen', 'leistungen', 'wurde', 'campos', 'racing', 'aufmerksam', 'verpflichtete', 'schliesslich', 'fu', 'r', 'letzten', 'vier', 'sieben', 'rennwochenenden', 'auto', 'gp']
# ['erzielte', 'anhieb', 'pole', 'position', 'zweiten', 'platz', 'dahin', 'beste', 'platzierung', 'teams', 'darstellte']
# ['wenige', 'tage', 'ersten', 'auto', 'gp', 'einsatz', 'erhielt', 'mo', 'glichkeit', 'super', 'nova', 'racing', 'gp', 'serie', 'zuru', 'ckzukehren']
# ['wegen', 'terminu', 'berschneidungen', 'trat', 'daher', 'auto', 'gp', 'veranstaltung']
# ['sieg', 'beim', 'saisonfinale', 'beendete', 'auto', 'gp', 'saison', 'zehnten', 'position', 'fahrerwertung']
# ['gp', 'serie', 'absolvierte', 'zweite', 'saisonha', 'lfte']
# ['zwei', 'fu', 'nften', 'pla', 'tzen', 'beste', 'resultate', 'schloss', 'saison']
# ['gesamtrang', 'ab']
# ['setzte', 'teamintern', 'fairuz', 'fauzy', 'komplette', 'saison', 'bestritten']
# ['carroll', 'permanentes', 'engagement']
# ['zog', 'formelsport', 'zuru', 'ck', 'wechselte', 'gt', 'sport']
# ['fu', 'r', 'belgian', 'audi', 'club', 'team', 'wrt', 'nahm', 'zwei', 'rennen', 'fia', 'gt', 'weltmeisterschaft', 'teil']
# ['dabei', 'wurde', 'zusammen', 'teamkollegen', 'laurens', 'vanthoor', 'zweiter']
# ['ferner', 'ging', 'rennen', 'blancpain', 'endurance', 'series', 'fu', 'r', 'vita', 'one', 'racing', 'team', 'start']
# ['fu', 'r', 'blancpain', 'endurance', 'series', 'erhielt', 'carroll', 'festes', 'cockpit', 'gulf', 'racing']
# ['gemeinsam', 'teamkollegen', 'rob', 'bell', 'nico', 'verdonck', 'beendete', 'saison']
# ['platz', 'pro', 'wertung']
# ['wechselte', 'carroll', 'european', 'le', 'mans', 'series', 'blieb', 'gulf', 'racing']
# ['wurde', 'elfter', 'gte', 'wertung']
# ['ausserdem', 'fuhr', 'fu', 'nf', 'rennen', 'britischen', 'gt', 'meisterschaft']
# ['trat', 'carroll', 'erneut', 'fu', 'r', 'gulf', 'racing', 'elms']
# ['teamkollegen', 'phil', 'keen', 'mike', 'wainwright', 'gewann', 'gte', 'wertung']
# ['fahrer', 'gte', 'wertung', 'erreichten', 'carroll', 'wainwright', 'vierten', 'rang']
# ['ferner', 'startete', 'abermals', 'rennen', 'britischen', 'gt', 'meisterschaft']
# ['debu', 'tierte', 'carroll', 'fia', 'langstrecken', 'weltmeisterschaft']
# ['zusammen', 'ben', 'barker', 'wainwright', 'ging', 'fu', 'r', 'gulf', 'racing', 'start']
# ['rahmen', 'weltmeisterschaft', 'debu', 'tierte', 'carroll', 'zudem', 'beim', 'stunden', 'rennen', 'le', 'mans']
# ['carroll', 'barker', 'wainwright', 'beendeten', 'saison']
# ['platz', 'gt', 'weltcup']
# ['ausserdem', 'nahm', 'erneut', 'rennen', 'britischen', 'gt', 'meisterschaft', 'teil', 'fuhr', 'einzelne', 'rennen', 'international', 'gt', 'open']
# ['daru', 'ber', 'hinaus', 'kehrte', 'carroll', 'saison', 'formelsport', 'zuru', 'ck']
# ['erhielt', 'fia', 'formel', 'e', 'meisterschaft', 'cockpit', 'jaguar', 'racing', 'neu', 'meisterschaft', 'eingestiegen']
# ['voll', 'formel', 'e', 'konzentrieren', 'entschied', 'carroll', 'dagegen', 'engagement', 'fia', 'langstrecken', 'weltmeisterschaft', 'weiterzufu', 'hren']
# ['dritten', 'rennen', 'belegte']
# ['gesamtrang']
# ['gela', 'nde', 'reihe', 'thematischer', 'pavillons', 'wurde', 'all', 'unions', 'landwirtschaftsausstellung', 'angelegt', 'zuna', 'chst', 'betrieb']
# ['wa', 'hrend', 'zweiten', 'weltkriegs', 'wurde', 'ausstellung', 'geschlossen', 'konnte', 'rekonstruierten', 'neu', 'errichteten', 'pavillons']
# ['august', 'wiederero', 'ffnet']
# ['saison', 'ging', 'landwirtschaftsausstellung', 'erweitertem', 'territorium', 'ausstellung', 'volkswirtschaftlichen', 'errungenschaften', 'udssr']
# ['schau', 'errungenschaften', 'sozialismus', 'gedacht', 'galt', 'sowjetunion', 'vorzeigeobjekt', 'leistungssta', 'rke', 'sowjetischen', 'planwirtschaft', 'demonstrierte']
# ['etwa', 'einhundert', 'teil', 'aufwa', 'ndig', 'gestalteten', 'pavillons', 'befanden', 'ausstellungsstu', 'cke', 'mehreren', 'regionen', 'la', 'ndern', 'verschiedenen', 'gebieten', 'volkswirtschaft']
# ['besondere', 'bekanntheit', 'errang', 'pavillon', 'weltraumfahrt']
# ['konnten', 'exemplare', 'sputnik', 'satelliten', 'trainingsgera', 'te', 'vorbereitung', 'kosmonauten', 'raumanzu', 'ge', 'teile', 'sojus', 'raketen', 'besichtigt']
# ['auflo', 'sung', 'sowjetunion', 'wurden', 'pavillons', 'ausgera', 'umt', 'marktfla', 'che', 'vermietet', 'moskauern', 'stand', 'wdnch', 'lange', 'zeit', 'fu', 'r', 'einkauf', 'unterhaltungselektronik']
# ['wurde', 'offene', 'aktiengesellschaft', 'umgewandelt', 'erhielt', 'namen', 'allrussisches', 'ausstellungszentrum']
# ['metrostation', 'wdnch', 'wurde', 'jedoch', 'umbenannt']
# ['ab', 'wurde', 'wwz', 'messeplatz', 'ausgebaut']
# ['beherbergte', 'fach', 'publikumsmessen', 'u', 'a']
# ['internationale', 'handwerksmesse', 'deutscher', 'kooperation']
# ['gela', 'nde', 'wurde', 'weiterhin', 'erholungspark', 'sowie', 'fu', 'r', 'kultur', 'vergnu', 'gungs', 'sportveranstaltungen', 'genutzt']
# ['zieht', 'ja', 'hrlich', 'zirka', 'millionen', 'besucher']
# ['ausstellungsgela', 'nde', 'bzw']
# ['unmittelbaren', 'na', 'he', 'befinden', 'ausserdem', 'anfang', 'u', 'bernahm', 'stadt', 'moskau', 'anteile', 'oao', 'wwz']
# ['anregung', 'moskauer', 'bu', 'rgermeisters', 'fand', 'online', 'umfrage', 'statt', 'mehr', 'teilnehmenden', 'moskauer', 'fu', 'r', 'ru', 'ckkehr', 'vorherigen', 'namen', 'stimmten']
# ['ausstellungsgela', 'nde', 'wurde', 'daraufhin']
# ['mai', 'wdnch', 'zuru', 'ckbenannt']
# ['ende', 'juli', 'wurde', 'botanische', 'nikolai', 'zizin', 'garten', 'ostankino', 'park', 'fernsehturm', 'ostankino', 'wdnch', 'komplex', 'eingegliedert']
# ['elisabeth', 'tombrock', 'wurde', 'ahlen', 'tochter', 'ba', 'ckers', 'kolonialwarenha', 'ndlers', 'brauereibesitzers', 'geboren', 'gleichzeitig', 'gastwirtschaft', 'fu', 'hrte']
# ['studierte', 'pa', 'dagogik', 'wurde', 'lehrerin', 'mu', 'lheim', 'mo', 'hne']
# []
# ['august', 'wurde', 'lourdes', 'nachdem', 'zuvor', 'lungen', 'knochentuberkulose', 'erkrankt', 'wundersame', 'weise', 'geheilt']
# ['heilung', 'bewogen', 'gru', 'ndete', 'zusammen', 'missionsbischof', 'pra', 'laten', 'santare', 'm', 'amandus', 'bahlmann', 'ofm', 'ordensgemeinschaft', 'namen', 'missionsclarissen', 'spa', 'ter', 'missionsschwestern', 'unbefleckten', 'empfa', 'ngnis', 'mutter', 'gottes', 'erweitert', 'wurde']
# ['offizielle', 'titel', 'organisation', 'lautet', 'mutter', 'immaculata']
# ['starb']

# %%
forest = RandomForestClassifier(n_estimators = 100)
print("Fitting a random forest to labeled training data...")
forest = forest.fit(trainDataVecs, train_df['sim_sent'])

# %%
# remove instances in test set that could not be represented as feature vectors
nan_indices = list({x for x,y in np.argwhere(np.isnan(testDataVecs))})
if len(nan_indices) > 0:
    print('Removing {:d} instances from test set.'.format(len(nan_indices)))
    testDataVecs = np.delete(testDataVecs, nan_indices, axis=0)
    test_df.drop(test_df.iloc[nan_indices, :].index, axis=0, inplace=True)
    assert testDataVecs.shape[0] == len(test_df)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = forest.predict(testDataVecs)
print(classification_report(test_df['sim_sent'], result))
