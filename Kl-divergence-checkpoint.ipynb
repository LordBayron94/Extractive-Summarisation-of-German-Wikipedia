# %%
# !pip install sumy
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.kl import KLSummarizer
import pandas as pd, nltk
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# Requirement already satisfied: sumy in h:\anaconda\lib\site-packages (0.8.1)
# Requirement already satisfied: requests>=2.7.0 in h:\anaconda\lib\site-packages (from sumy) (2.25.1)
# Requirement already satisfied: nltk>=3.0.2 in h:\anaconda\lib\site-packages (from sumy) (3.6.1)
# Requirement already satisfied: breadability>=0.1.20 in h:\anaconda\lib\site-packages (from sumy) (0.1.20)
# Requirement already satisfied: pycountry>=18.2.23 in h:\anaconda\lib\site-packages (from sumy) (20.7.3)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in h:\anaconda\lib\site-packages (from sumy) (0.6.2)
# Requirement already satisfied: chardet in h:\anaconda\lib\site-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: lxml>=2.0 in h:\anaconda\lib\site-packages (from breadability>=0.1.20->sumy) (4.6.3)
# Requirement already satisfied: click in h:\anaconda\lib\site-packages (from nltk>=3.0.2->sumy) (7.1.2)
# Requirement already satisfied: joblib in h:\anaconda\lib\site-packages (from nltk>=3.0.2->sumy) (1.0.1)
# Requirement already satisfied: regex in h:\anaconda\lib\site-packages (from nltk>=3.0.2->sumy) (2021.4.4)
# Requirement already satisfied: tqdm in h:\anaconda\lib\site-packages (from nltk>=3.0.2->sumy) (4.59.0)
# Requirement already satisfied: certifi>=2017.4.17 in h:\anaconda\lib\site-packages (from requests>=2.7.0->sumy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in h:\anaconda\lib\site-packages (from requests>=2.7.0->sumy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in h:\anaconda\lib\site-packages (from requests>=2.7.0->sumy) (1.26.4)

# %%
df = pd.read_csv('G:/Extractive-Summarisation-of-German-Wikipedia/dataset/data_train.csv', encoding='utf-8')
test_df = df.head(50)
test_df
# Out:
#                                                source  \
# 0   Minghella war der Sohn italienisch-schottische...
# 1   Ende der 1940er Jahre wurde eine erste Auteur-...
# 2   Al Pacino, geboren in Manhattan, ist der Sohn ...
# 3   Der Name der Alkalimetalle leitet sich von dem...
# 4   Die Arbeit ist bereits seit dem Altertum Gegen...
# 5   Mit "Ampelkoalition" wird in Deutschland übli...
# 6   Im Mittelalter trat Ergotismus als Folge des V...
# 7   Arnims Vater war der wohlhabende Königlich Pr...
# 8   Es gibt drei klassische Aggregatzustände: Fü...
# 9   Börsenkurse sind dadurch gekennzeichnet, dass...
# 10  Ein Axiomensystem als Produkt der Axiomatisier...
# 11  Aktiva stehen auf der Aktivseite der Bilanz un...
# 12  Abu Nidal wurde im Mai 1937 am Hafen von Jaffa...
# 13  Die Arbeitgeberverbände entstanden in Reaktio...
# 14  Die boolesche Algebra ist nach George Boole be...
# 15  Der aus zwei alten Familien aus Devonshire sta...
# 16  Die Geschichte des Cha-Cha-Chas wurde nur mün...
# 17  Clive Staples Lewis wurde 1898 im nordirischen...
# 18  Im Jahr 1977 erreichten die Aktivitäten der s...
# 19  Beim Dixieland-Jazz treten im Vergleich zum tr...
# 20  Das im Osten angrenzende Département ist Alpe...
# 21  Die Vertreter der Doldenblütler sind fast aus...
# 22  Einsteinium wurde zusammen mit Fermium nach de...
# 23  Eiben-Arten sind immergrüne Sträucher oder k...
# 24  Edsger Dijkstra wurde als Sohn eines Chemikers...
# 25  Die Tochter eines Binnenschiffers und einer Fr...
# 26  Fermium wurde zusammen mit Einsteinium nach de...
# 27  Münteferings Vater war Landwirt, seine Mutter...
# 28  Kuhn wurde als Sohn eines einfachen Beamten, d...
# 29  Der aus zwei zusammengekuppelten Wagen bestehe...
# 30  Der Frankenwald liegt zwischen dem Thüringer ...
# 31  Die Wüste Gobi ist ein riesiges Trockengebiet...
# 32  Als Eiffels deutscher Stammvater gilt dem bish...
# 33  Vorgänger der grünen Sauce sind in Europa be...
# 34  Roddenberry wurde 1921 in El Paso in Texas geb...
# 35  Henry Cavendish war der Sohn von Lord Charles ...
# 36  Das Wort "Hektar" ist aus dem Französischen e...
# 37  Hans Bemmann wurde am 27. April 1922 in Groitz...
# 38  Halma wurde 1883 vom amerikanischen Chirurgen ...
# 39  In dem heute weit gefassten, auf molekulargene...
# 40  Der Hochtaunuskreis liegt fast vollständig im...
# 41  Hausstaubmilben sind etwa 0,1 bis 0,5 mm gross...
# 42  Nach dem Abitur 1961 am Kasseler Wilhelmsgymna...
# 43  Hohen Neuendorf erstreckt sich von der Havel i...
# 44  Die wichtigsten Versuche vor dem 19. Jahrhunde...
# 45  Die vollständige Induktion befasst sich mit d...
# 46  Ein Joule ist gleich der Energie, die benötig...
# 47  Der Ursprung des Namens "Jolly Roger" ist unbe...
# 48  Johann Christoph Adelung wurde am 8. August 17...
# 49  Leto wuchs unter anderem auf Haiti und in Colo...
#
#                                               summary
# 0   Anthony Minghella, CBE war ein britischer Film...
# 1   Die Auteur-Theorie ist eine Filmtheorie und di...
# 2   Alfredo James "Al" Pacino ist ein US-amerikani...
# 3   Als Alkalimetalle werden die chemischen Elemen...
# 4   Das deutsche Arbeitsrecht ist ein Rechtsgebiet...
# 5   Mit Ampelkoalition bezeichnet man die Zusammen...
# 6   Ergotismus oder Mutterkornvergiftung ist eine ...
# 7   Achim von Arnim war ein deutscher Schriftstell...
# 8   Als Aggregatzustände werden die unterschiedli...
# 9   Aussetzung des Handels ist eine Massnahme der ...
# 10  Ein Axiomensystem ist ein System von "grundleg...
# 11  Unter Aktiva versteht man die Summe des einem ...
# 12  Abu Nidal , eigentlicher Name Sabri Chalil al-...
# 13  Die Bundesvereinigung der Deutschen Arbeitgebe...
# 14  In der Mathematik ist eine boolesche Algebra e...
# 15  Charles Babbage war ein englischer Mathematike...
# 16  Der Cha-Cha-Cha [] ist ein moderner, paarweise...
# 17  C. S. Lewis war ein irischer Schriftsteller un...
# 18  Als Deutscher Herbst wird die Zeit und ihre po...
# 19  Die Stilrichtung des Dixieland entwickelte sic...
# 20  Das Département Var [] ist das französische ...
# 21  Die Doldenblütler oder Doldengewächse sind e...
# 22  Einsteinium ist ein ausschliesslich künstlich...
# 23  Die Eiben bilden eine Pflanzengattung in der F...
# 24  Edsger Wybe Dijkstra war ein niederländischer...
# 25  Edelgard Bulmahn ist eine deutsche Politikerin...
# 26  Fermium ist ein ausschliesslich künstlich erz...
# 27  Franz Müntefering ist ein deutscher Politiker...
# 28  Fritz Kuhn ist ein deutscher Politiker und Obe...
# 29  Der Verbrennungstriebwagen 877 war der erste D...
# 30  Der Frankenwald ist ein 300 bis hohes und 925 ...
# 31  Die Wüste Gobi, oder kurz die Gobi , ist ein ...
# 32  Alexandre Gustave Eiffel [] war ein französis...
# 33  Grüne Sauce ist in unterschiedlichen Variante...
# 34  Eugene Wesley "Gene" Roddenberry war ein ameri...
# 35  Henry Cavendish war ein britischer Naturwissen...
# 36  Das oder der Hektar, schweizerisch die Hektare...
# 37     Hans Bemmann war ein deutscher Schriftsteller.
# 38  Halma ist ein Brettspiel für bis zu sechs Per...
# 39  Die Heidekrautgewächse bilden eine Familie in...
# 40  Der Hochtaunuskreis ist eine Gebietskörpersch...
# 41  Die Hausstaubmilben sind eine Gattung der Milb...
# 42  Hans Eichel ist ein deutscher Politiker . Er w...
# 43  Hohen Neuendorf ist eine Stadt im Landkreis Ob...
# 44  Das Internationale Phonetische Alphabet ist ei...
# 45  Die vollständige Induktion ist eine mathemati...
# 46  Joule [] ist die abgeleitete SI-Einheit der En...
# 47  Der Jolly Roger oder "die Piratenflagge", häu...
# 48  Johann Christoph Adelung war ein deutscher Bib...
# 49  Jared Joseph Leto ist ein US-amerikanischer Sc...

# %%
stopword_list = nltk.corpus.stopwords.words('german')
LANGUAGE = "german"
def remove_stopwords(text):
    filtered_words = [word for word in nltk.word_tokenize(text) if word not in stopword_list]
    filtered_text = ' '.join(filtered_words)
    return filtered_text

def KLdiv(df, size):
    lst = []
    parser = PlaintextParser.from_string(df, Tokenizer(LANGUAGE))
    summarizer = KLSummarizer()
    summary = summarizer(parser.document, size)
    for s in summarizer(parser.document, size):
        lst.append(s)
    string = ' '.join([str(e) for e in lst])
    return string

# %%
print(KLdiv(test_df['source'][0], 1))
# Out:
# Gegen Ende seines Lebens kehrte Minghella zu seinen Anfängen im Radio und auf der Bühne zurück: 2006 wurde sein Hörspiel "Eyes Down Looking" mit Jude Law zu Ehren von Samuel Beckett auf BBC Radio 3 ausgestrahlt, ein Jahr zuvor hatte seine Inszenierung der Puccini-Oper Madame Butterfly in der English National Opera in London Premiere und wurde auch in der Nationaloper von Vilnius und in der Metropolitan Opera in New York gezeigt.

# %%
test_df['kl1'] = test_df.apply(lambda x: KLdiv(x['source'], 1), axis=1)
test_df['kl2'] = test_df.apply(lambda x: KLdiv(x['source'], 2), axis=1)
test_df['kl5'] = test_df.apply(lambda x: KLdiv(x['source'], 5), axis=1)
test_df['kl10'] = test_df.apply(lambda x: KLdiv(x['source'], 10,), axis=1)
test_df.to_csv('G:/Extractive-Summarisation-of-German-Wikipedia/dataset/kl_divRez.csv')
# Out:
# <ipython-input-5-3688e27245a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['kl1'] = test_df.apply(lambda x: KLdiv(x['source'], 1), axis=1)

# %%
from rouge import Rouge
import sys

sys.stdout = open("G:/Extractive-Summarisation-of-German-Wikipedia/dataset/test.txt", "w")

hy, rf = test_df['kl1'], test_df['summary']
rouge= Rouge()
scoresT1= rouge.get_scores(hy, rf, avg=True)
print("Kl_div1 scores: ", scoresT1, '\n\n')

hy2 = test_df['kl2']
scoresT2= rouge.get_scores(hy2, rf, avg=True)
print("Kl_div2 scores: ", scoresT2, '\n\n')

hy5 = test_df['kl5']
scoresT5= rouge.get_scores(hy5, rf, avg=True)
print("Kl_div5 scores: ", scoresT5, '\n\n')

hy10 = test_df['Kl_div10']
scoresT10= rouge.get_scores(hy10, rf, avg=True)
print("Kl_div10 scores: ", scoresT10, '\n\n')

sys.stdout.close()
